# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# <h1>Exploratory Data Analysis</h1>

# %%
df = pd.read_csv('classification_data.csv')
df.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# 2                                  2  ...                       5
# 3                                  5  ...                       2
# 4                                  3  ...                       3
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
#
#    Arrival Delay in Minutes             satisfaction
# 0                      18.0  neutral or dissatisfied
# 1                       6.0  neutral or dissatisfied
# 2                       0.0                satisfied
# 3                       9.0  neutral or dissatisfied
# 4                       0.0                satisfied
#
# [5 rows x 25 columns]

# %%
df.drop(columns=['Unnamed: 0','id'],inplace=True)
df.head()
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1    Male  disloyal Customer   25  Business travel  Business              235
# 2  Female     Loyal Customer   26  Business travel  Business             1142
# 3  Female     Loyal Customer   25  Business travel  Business              562
# 4    Male     Loyal Customer   61  Business travel  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       3              1  ...                       5
# 1                       3              3  ...                       1
# 2                       2              2  ...                       5
# 3                       5              5  ...                       2
# 4                       3              3  ...                       3
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
#
#    Arrival Delay in Minutes             satisfaction
# 0                      18.0  neutral or dissatisfied
# 1                       6.0  neutral or dissatisfied
# 2                       0.0                satisfied
# 3                       9.0  neutral or dissatisfied
# 4                       0.0                satisfied
#
# [5 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Gender                                object
# Customer Type                         object
# Age                                    int64
# Type of Travel                        object
# Class                                 object
# Flight Distance                        int64
# Inflight wifi service                  int64
# Departure/Arrival time convenient      int64
# Ease of Online booking                 int64
# Gate location                          int64
# Food and drink                         int64
# Online boarding                        int64
# Seat comfort                           int64
# Inflight entertainment                 int64
# On-board service                       int64
# Leg room service                       int64
# Baggage handling                       int64
# Checkin service                        int64
# Inflight service                       int64
# Cleanliness                            int64
# Departure Delay in Minutes             int64
# Arrival Delay in Minutes             float64
# satisfaction                          object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             103904 non-null  object
#  1   Customer Type                      103904 non-null  object
#  2   Age                                103904 non-null  int64
#  3   Type of Travel                     103904 non-null  object
#  4   Class                              103904 non-null  object
#  5   Flight Distance                    103904 non-null  int64
#  6   Inflight wifi service              103904 non-null  int64
#  7   Departure/Arrival time convenient  103904 non-null  int64
#  8   Ease of Online booking             103904 non-null  int64
#  9   Gate location                      103904 non-null  int64
#  10  Food and drink                     103904 non-null  int64
#  11  Online boarding                    103904 non-null  int64
#  12  Seat comfort                       103904 non-null  int64
#  13  Inflight entertainment             103904 non-null  int64
#  14  On-board service                   103904 non-null  int64
#  15  Leg room service                   103904 non-null  int64
#  16  Baggage handling                   103904 non-null  int64
#  17  Checkin service                    103904 non-null  int64
#  18  Inflight service                   103904 non-null  int64
#  19  Cleanliness                        103904 non-null  int64
#  20  Departure Delay in Minutes         103904 non-null  int64
#  21  Arrival Delay in Minutes           103594 non-null  float64
#  22  satisfaction                       103904 non-null  object
# dtypes: float64(1), int64(17), object(5)
# memory usage: 18.2+ MB

# %%
df.isna().sum()
# Out:
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# satisfaction                           0
# dtype: int64

# %%
df.shape
# Out:
# (103904, 23)

# %%
len(df)
# Out:
# 103904

# %%
df.describe()
# Out:
#                  Age  Flight Distance  Inflight wifi service  \
# count  103904.000000    103904.000000          103904.000000
# mean       39.379706      1189.448375               2.729683
# std        15.114964       997.147281               1.327829
# min         7.000000        31.000000               0.000000
# 25%        27.000000       414.000000               2.000000
# 50%        40.000000       843.000000               3.000000
# 75%        51.000000      1743.000000               4.000000
# max        85.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      103904.000000           103904.000000
# mean                            3.060296                2.756901
# std                             1.525075                1.398929
# min                             0.000000                0.000000
# 25%                             2.000000                2.000000
# 50%                             3.000000                3.000000
# 75%                             4.000000                4.000000
# max                             5.000000                5.000000
#
#        Gate location  Food and drink  Online boarding   Seat comfort  \
# count  103904.000000   103904.000000    103904.000000  103904.000000
# mean        2.976883        3.202129         3.250375       3.439396
# std         1.277621        1.329533         1.349509       1.319088
# min         0.000000        0.000000         0.000000       0.000000
# 25%         2.000000        2.000000         2.000000       2.000000
# 50%         3.000000        3.000000         3.000000       4.000000
# 75%         4.000000        4.000000         4.000000       5.000000
# max         5.000000        5.000000         5.000000       5.000000
#
#        Inflight entertainment  On-board service  Leg room service  \
# count           103904.000000     103904.000000     103904.000000
# mean                 3.358158          3.382363          3.351055
# std                  1.332991          1.288354          1.315605
# min                  0.000000          0.000000          0.000000
# 25%                  2.000000          2.000000          2.000000
# 50%                  4.000000          4.000000          4.000000
# 75%                  4.000000          4.000000          4.000000
# max                  5.000000          5.000000          5.000000
#
#        Baggage handling  Checkin service  Inflight service    Cleanliness  \
# count     103904.000000    103904.000000     103904.000000  103904.000000
# mean           3.631833         3.304290          3.640428       3.286351
# std            1.180903         1.265396          1.175663       1.312273
# min            1.000000         0.000000          0.000000       0.000000
# 25%            3.000000         3.000000          3.000000       2.000000
# 50%            4.000000         3.000000          4.000000       3.000000
# 75%            5.000000         4.000000          5.000000       4.000000
# max            5.000000         5.000000          5.000000       5.000000
#
#        Departure Delay in Minutes  Arrival Delay in Minutes
# count               103904.000000             103594.000000
# mean                    14.815618                 15.178678
# std                     38.230901                 38.698682
# min                      0.000000                  0.000000
# 25%                      0.000000                  0.000000
# 50%                      0.000000                  0.000000
# 75%                     12.000000                 13.000000
# max                   1592.000000               1584.000000

# %%
#Number distinct values in each feature
df.nunique()
# Out:
# Gender                                  2
# Customer Type                           2
# Age                                    75
# Type of Travel                          2
# Class                                   3
# Flight Distance                      3802
# Inflight wifi service                   6
# Departure/Arrival time convenient       6
# Ease of Online booking                  6
# Gate location                           6
# Food and drink                          6
# Online boarding                         6
# Seat comfort                            6
# Inflight entertainment                  6
# On-board service                        6
# Leg room service                        6
# Baggage handling                        5
# Checkin service                         6
# Inflight service                        6
# Cleanliness                             6
# Departure Delay in Minutes            446
# Arrival Delay in Minutes              455
# satisfaction                            2
# dtype: int64

# %%
df.corr()
# Out:
#                                         Age  Flight Distance  \
# Age                                1.000000         0.099461
# Flight Distance                    0.099461         1.000000
# Inflight wifi service              0.017859         0.007131
# Departure/Arrival time convenient  0.038125        -0.020043
# Ease of Online booking             0.024842         0.065717
# Gate location                     -0.001330         0.004793
# Food and drink                     0.023000         0.056994
# Online boarding                    0.208939         0.214869
# Seat comfort                       0.160277         0.157333
# Inflight entertainment             0.076444         0.128740
# On-board service                   0.057594         0.109526
# Leg room service                   0.040583         0.133916
# Baggage handling                  -0.047529         0.063184
# Checkin service                    0.035482         0.073072
# Inflight service                  -0.049427         0.057540
# Cleanliness                        0.053611         0.093149
# Departure Delay in Minutes        -0.010152         0.002158
# Arrival Delay in Minutes          -0.012147        -0.002426
#
#                                    Inflight wifi service  \
# Age                                             0.017859
# Flight Distance                                 0.007131
# Inflight wifi service                           1.000000
# Departure/Arrival time convenient               0.343845
# Ease of Online booking                          0.715856
# Gate location                                   0.336248
# Food and drink                                  0.134718
# Online boarding                                 0.456970
# Seat comfort                                    0.122658
# Inflight entertainment                          0.209321
# On-board service                                0.121500
# Leg room service                                0.160473
# Baggage handling                                0.120923
# Checkin service                                 0.043193
# Inflight service                                0.110441
# Cleanliness                                     0.132698
# Departure Delay in Minutes                     -0.017402
# Arrival Delay in Minutes                       -0.019095
#
#                                    Departure/Arrival time convenient  \
# Age                                                         0.038125
# Flight Distance                                            -0.020043
# Inflight wifi service                                       0.343845
# Departure/Arrival time convenient                           1.000000
# Ease of Online booking                                      0.436961
# Gate location                                               0.444757
# Food and drink                                              0.004906
# Online boarding                                             0.070119
# Seat comfort                                                0.011344
# Inflight entertainment                                     -0.004861
# On-board service                                            0.068882
# Leg room service                                            0.012441
# Baggage handling                                            0.072126
# Checkin service                                             0.093333
# Inflight service                                            0.073318
# Cleanliness                                                 0.014292
# Departure Delay in Minutes                                  0.001005
# Arrival Delay in Minutes                                   -0.000864
#
#                                    Ease of Online booking  Gate location  \
# Age                                              0.024842      -0.001330
# Flight Distance                                  0.065717       0.004793
# Inflight wifi service                            0.715856       0.336248
# Departure/Arrival time convenient                0.436961       0.444757
# Ease of Online booking                           1.000000       0.458655
# Gate location                                    0.458655       1.000000
# Food and drink                                   0.031873      -0.001159
# Online boarding                                  0.404074       0.001688
# Seat comfort                                     0.030014       0.003669
# Inflight entertainment                           0.047032       0.003517
# On-board service                                 0.038833      -0.028373
# Leg room service                                 0.107601      -0.005873
# Baggage handling                                 0.038762       0.002313
# Checkin service                                  0.011081      -0.035427
# Inflight service                                 0.035272       0.001681
# Cleanliness                                      0.016179      -0.003830
# Departure Delay in Minutes                      -0.006371       0.005467
# Arrival Delay in Minutes                        -0.007984       0.005143
#
#                                    Food and drink  Online boarding  \
# Age                                      0.023000         0.208939
# Flight Distance                          0.056994         0.214869
# Inflight wifi service                    0.134718         0.456970
# Departure/Arrival time convenient        0.004906         0.070119
# Ease of Online booking                   0.031873         0.404074
# Gate location                           -0.001159         0.001688
# Food and drink                           1.000000         0.234468
# Online boarding                          0.234468         1.000000
# Seat comfort                             0.574556         0.420211
# Inflight entertainment                   0.622512         0.285066
# On-board service                         0.059073         0.155443
# Leg room service                         0.032498         0.123950
# Baggage handling                         0.034746         0.083280
# Checkin service                          0.087299         0.204462
# Inflight service                         0.033993         0.074573
# Cleanliness                              0.657760         0.331517
# Departure Delay in Minutes              -0.029926        -0.018982
# Arrival Delay in Minutes                -0.032524        -0.021949
#
#                                    Seat comfort  Inflight entertainment  \
# Age                                    0.160277                0.076444
# Flight Distance                        0.157333                0.128740
# Inflight wifi service                  0.122658                0.209321
# Departure/Arrival time convenient      0.011344               -0.004861
# Ease of Online booking                 0.030014                0.047032
# Gate location                          0.003669                0.003517
# Food and drink                         0.574556                0.622512
# Online boarding                        0.420211                0.285066
# Seat comfort                           1.000000                0.610590
# Inflight entertainment                 0.610590                1.000000
# On-board service                       0.131971                0.420153
# Leg room service                       0.105559                0.299692
# Baggage handling                       0.074542                0.378210
# Checkin service                        0.191854                0.120867
# Inflight service                       0.069218                0.404855
# Cleanliness                            0.678534                0.691815
# Departure Delay in Minutes            -0.027898               -0.027489
# Arrival Delay in Minutes              -0.029900               -0.030703
#
#                                    On-board service  Leg room service  \
# Age                                        0.057594          0.040583
# Flight Distance                            0.109526          0.133916
# Inflight wifi service                      0.121500          0.160473
# Departure/Arrival time convenient          0.068882          0.012441
# Ease of Online booking                     0.038833          0.107601
# Gate location                             -0.028373         -0.005873
# Food and drink                             0.059073          0.032498
# Online boarding                            0.155443          0.123950
# Seat comfort                               0.131971          0.105559
# Inflight entertainment                     0.420153          0.299692
# On-board service                           1.000000          0.355495
# Leg room service                           0.355495          1.000000
# Baggage handling                           0.519134          0.369544
# Checkin service                            0.243914          0.153137
# Inflight service                           0.550782          0.368656
# Cleanliness                                0.123220          0.096370
# Departure Delay in Minutes                -0.031569          0.014363
# Arrival Delay in Minutes                  -0.035227          0.011843
#
#                                    Baggage handling  Checkin service  \
# Age                                       -0.047529         0.035482
# Flight Distance                            0.063184         0.073072
# Inflight wifi service                      0.120923         0.043193
# Departure/Arrival time convenient          0.072126         0.093333
# Ease of Online booking                     0.038762         0.011081
# Gate location                              0.002313        -0.035427
# Food and drink                             0.034746         0.087299
# Online boarding                            0.083280         0.204462
# Seat comfort                               0.074542         0.191854
# Inflight entertainment                     0.378210         0.120867
# On-board service                           0.519134         0.243914
# Leg room service                           0.369544         0.153137
# Baggage handling                           1.000000         0.233122
# Checkin service                            0.233122         1.000000
# Inflight service                           0.628561         0.237197
# Cleanliness                                0.095793         0.179583
# Departure Delay in Minutes                -0.005573        -0.018453
# Arrival Delay in Minutes                  -0.008542        -0.020369
#
#                                    Inflight service  Cleanliness  \
# Age                                       -0.049427     0.053611
# Flight Distance                            0.057540     0.093149
# Inflight wifi service                      0.110441     0.132698
# Departure/Arrival time convenient          0.073318     0.014292
# Ease of Online booking                     0.035272     0.016179
# Gate location                              0.001681    -0.003830
# Food and drink                             0.033993     0.657760
# Online boarding                            0.074573     0.331517
# Seat comfort                               0.069218     0.678534
# Inflight entertainment                     0.404855     0.691815
# On-board service                           0.550782     0.123220
# Leg room service                           0.368656     0.096370
# Baggage handling                           0.628561     0.095793
# Checkin service                            0.237197     0.179583
# Inflight service                           1.000000     0.088779
# Cleanliness                                0.088779     1.000000
# Departure Delay in Minutes                -0.054813    -0.014093
# Arrival Delay in Minutes                  -0.059196    -0.015774
#
#                                    Departure Delay in Minutes  \
# Age                                                 -0.010152
# Flight Distance                                      0.002158
# Inflight wifi service                               -0.017402
# Departure/Arrival time convenient                    0.001005
# Ease of Online booking                              -0.006371
# Gate location                                        0.005467
# Food and drink                                      -0.029926
# Online boarding                                     -0.018982
# Seat comfort                                        -0.027898
# Inflight entertainment                              -0.027489
# On-board service                                    -0.031569
# Leg room service                                     0.014363
# Baggage handling                                    -0.005573
# Checkin service                                     -0.018453
# Inflight service                                    -0.054813
# Cleanliness                                         -0.014093
# Departure Delay in Minutes                           1.000000
# Arrival Delay in Minutes                             0.965481
#
#                                    Arrival Delay in Minutes
# Age                                               -0.012147
# Flight Distance                                   -0.002426
# Inflight wifi service                             -0.019095
# Departure/Arrival time convenient                 -0.000864
# Ease of Online booking                            -0.007984
# Gate location                                      0.005143
# Food and drink                                    -0.032524
# Online boarding                                   -0.021949
# Seat comfort                                      -0.029900
# Inflight entertainment                            -0.030703
# On-board service                                  -0.035227
# Leg room service                                   0.011843
# Baggage handling                                  -0.008542
# Checkin service                                   -0.020369
# Inflight service                                  -0.059196
# Cleanliness                                       -0.015774
# Departure Delay in Minutes                         0.965481
# Arrival Delay in Minutes                           1.000000

# %% [markdown]
# <h1>Visualisation</h1>

# %%
sns.set_context("paper", font_scale=1)
sns.distplot(df['Arrival Delay in Minutes'],bins=30)
# Out:
# /home/meghadharsan/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Arrival Delay in Minutes', ylabel='Density'>

# %% [markdown]
# <h4>Since the distribution here is <u>Positively skewed</u>, we choose the median of available data to fill the Null vales.<br>If the distributed is not skewed we would choose mean to fill the Null values</h4>

# %% [markdown]
# <h3>Count plots for all the Categorical Features</h3>

# %%
sns.set_context('paper',font_scale=1.5)
plt.figure(figsize=(15,15))
plt.subplot(2,2,1)
sns.countplot(df['Gender'])
plt.subplot(2,2,2)
sns.countplot(df['Customer Type'])
plt.subplot(2,2,3)
sns.countplot(df['Type of Travel'])
plt.subplot(2,2,4)
sns.countplot(df['Class'])
# Out:
# /home/meghadharsan/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/meghadharsan/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/meghadharsan/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/meghadharsan/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %% [markdown]
# <h3>Plots to analyse continuous valued Features</h3>

# %%
columns = list(df.columns)
continuousFeatures = []
for i in columns:
    if isinstance(df[i][0],np.float64):
        continuousFeatures.append(i)
print("List of all Continuous Features")
continuousFeatures
# Out:
# List of all Continuous Features
# ['Arrival Delay in Minutes']

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
sns.histplot(df['Age'])
plt.subplot(1,2,2)
sns.histplot(df['Flight Distance'])
# Out:
# <AxesSubplot:xlabel='Flight Distance', ylabel='Count'>

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
sns.distplot(df['Departure Delay in Minutes'])
plt.subplot(1,2,2)
sns.distplot(df['Arrival Delay in Minutes'])
# Out:
# /home/meghadharsan/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/meghadharsan/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Arrival Delay in Minutes', ylabel='Density'>

# %% [markdown]
# <h4>As we can see, the plots look similar. Same inference from Heat-Map. These two variables had high correlation coefficient</h4>

# %%
sns.scatterplot(df['Arrival Delay in Minutes'],df['Departure Delay in Minutes'])
# Out:
# /home/meghadharsan/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Arrival Delay in Minutes', ylabel='Departure Delay in Minutes'>

# %%
df.groupby('satisfaction').size().plot(kind='pie',y="",autopct='%1.0f%%')
plt.legend()

# %%
sample = df.copy()
sample = sample[(sample['Flight Distance']<=1000)]
sample.groupby('satisfaction').size().plot(kind='pie',y="",autopct='%1.0f%%')
plt.legend()

# %%
plt.figure(figsize=(7,7))
sample1 = df.copy()
sample1 = sample1[(sample1['Flight Distance']<=1000)]
sample1.groupby('Cleanliness').size().plot(kind='pie',y="",autopct='%1.0f%%')
plt.legend()

# %%
sns.violinplot(df['Cleanliness'],df['satisfaction'])
# Out:
# /home/meghadharsan/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Cleanliness', ylabel='satisfaction'>

# %% [markdown]
# <h4> Though 'Flight Distance' b/w 0 and 1000 has the highest frequency , 67% of the customers are dissatisfied</h4>

# %%
df.head()
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1    Male  disloyal Customer   25  Business travel  Business              235
# 2  Female     Loyal Customer   26  Business travel  Business             1142
# 3  Female     Loyal Customer   25  Business travel  Business              562
# 4    Male     Loyal Customer   61  Business travel  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       3              1  ...                       5
# 1                       3              3  ...                       1
# 2                       2              2  ...                       5
# 3                       5              5  ...                       2
# 4                       3              3  ...                       3
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
#
#    Arrival Delay in Minutes             satisfaction
# 0                      18.0  neutral or dissatisfied
# 1                       6.0  neutral or dissatisfied
# 2                       0.0                satisfied
# 3                       9.0  neutral or dissatisfied
# 4                       0.0                satisfied
#
# [5 rows x 23 columns]

# %% [markdown]
# <h1>Data Preprocessing</h1>

# %%
#Encoding Gender Variable
df["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df["Gender"] = df["Gender"].map({"Male":0,"Female":1})
df
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 0            0     Loyal Customer   13  Personal Travel  Eco Plus
# 1            0  disloyal Customer   25  Business travel  Business
# 2            1     Loyal Customer   26  Business travel  Business
# 3            1     Loyal Customer   25  Business travel  Business
# 4            0     Loyal Customer   61  Business travel  Business
# ...        ...                ...  ...              ...       ...
# 103899       1  disloyal Customer   23  Business travel       Eco
# 103900       0     Loyal Customer   49  Business travel  Business
# 103901       0  disloyal Customer   30  Business travel  Business
# 103902       1  disloyal Customer   22  Business travel       Eco
# 103903       0     Loyal Customer   27  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 0                   460                      3
# 1                   235                      3
# 2                  1142                      2
# 3                   562                      2
# 4                   214                      3
# ...                 ...                    ...
# 103899              192                      2
# 103900             2347                      4
# 103901             1995                      1
# 103902             1000                      1
# 103903             1723                      1
#
#         Departure/Arrival time convenient  Ease of Online booking  \
# 0                                       4                       3
# 1                                       2                       3
# 2                                       2                       2
# 3                                       5                       5
# 4                                       3                       3
# ...                                   ...                     ...
# 103899                                  1                       2
# 103900                                  4                       4
# 103901                                  1                       1
# 103902                                  1                       1
# 103903                                  3                       3
#
#         Gate location  ...  Inflight entertainment  On-board service  \
# 0                   1  ...                       5                 4
# 1                   3  ...                       1                 1
# 2                   2  ...                       5                 4
# 3                   5  ...                       2                 2
# 4                   3  ...                       3                 3
# ...               ...  ...                     ...               ...
# 103899              3  ...                       2                 3
# 103900              4  ...                       5                 5
# 103901              3  ...                       4                 3
# 103902              5  ...                       1                 4
# 103903              3  ...                       1                 1
#
#         Leg room service  Baggage handling  Checkin service  Inflight service  \
# 0                      3                 4                4                 5
# 1                      5                 3                1                 4
# 2                      3                 4                4                 4
# 3                      5                 3                1                 4
# 4                      4                 4                3                 3
# ...                  ...               ...              ...               ...
# 103899                 1                 4                2                 3
# 103900                 5                 5                5                 5
# 103901                 2                 4                5                 5
# 103902                 5                 1                5                 4
# 103903                 1                 4                4                 3
#
#         Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0                 5                          25                      18.0
# 1                 1                           1                       6.0
# 2                 5                           0                       0.0
# 3                 2                          11                       9.0
# 4                 3                           0                       0.0
# ...             ...                         ...                       ...
# 103899            2                           3                       0.0
# 103900            4                           0                       0.0
# 103901            4                           7                      14.0
# 103902            1                           0                       0.0
# 103903            1                           0                       0.0
#
#                    satisfaction
# 0       neutral or dissatisfied
# 1       neutral or dissatisfied
# 2                     satisfied
# 3       neutral or dissatisfied
# 4                     satisfied
# ...                         ...
# 103899  neutral or dissatisfied
# 103900                satisfied
# 103901  neutral or dissatisfied
# 103902  neutral or dissatisfied
# 103903  neutral or dissatisfied
#
# [103904 rows x 23 columns]

# %%
#Encoding Customer Type
df["Customer Type"].unique()
# Out:
# array(['Loyal Customer', 'disloyal Customer'], dtype=object)

# %%
df["Customer Type"] = df["Customer Type"].map({"Loyal Customer":0,"disloyal Customer":1})

# %%
df.head()
# Out:
#    Gender  Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0       0              0   13  Personal Travel  Eco Plus              460
# 1       0              1   25  Business travel  Business              235
# 2       1              0   26  Business travel  Business             1142
# 3       1              0   25  Business travel  Business              562
# 4       0              0   61  Business travel  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       3              1  ...                       5
# 1                       3              3  ...                       1
# 2                       2              2  ...                       5
# 3                       5              5  ...                       2
# 4                       3              3  ...                       3
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
#
#    Arrival Delay in Minutes             satisfaction
# 0                      18.0  neutral or dissatisfied
# 1                       6.0  neutral or dissatisfied
# 2                       0.0                satisfied
# 3                       9.0  neutral or dissatisfied
# 4                       0.0                satisfied
#
# [5 rows x 23 columns]

# %%
#Encoding satisfaction variable
df["satisfaction"].unique()
# Out:
# array(['neutral or dissatisfied', 'satisfied'], dtype=object)

# %%
df["satisfaction"] = df["satisfaction"].map({"neutral or dissatisfied":0,"satisfied":1})

# %%
df.head()
# Out:
#    Gender  Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0       0              0   13  Personal Travel  Eco Plus              460
# 1       0              1   25  Business travel  Business              235
# 2       1              0   26  Business travel  Business             1142
# 3       1              0   25  Business travel  Business              562
# 4       0              0   61  Business travel  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       3              1  ...                       5
# 1                       3              3  ...                       1
# 2                       2              2  ...                       5
# 3                       5              5  ...                       2
# 4                       3              3  ...                       3
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
#
#    Arrival Delay in Minutes  satisfaction
# 0                      18.0             0
# 1                       6.0             0
# 2                       0.0             1
# 3                       9.0             0
# 4                       0.0             1
#
# [5 rows x 23 columns]

# %%
#Encoding Type of Travel
df["Type of Travel"].unique()
# Out:
# array(['Personal Travel', 'Business travel'], dtype=object)

# %%
df["Type of Travel"] = df["Type of Travel"].map({'Personal Travel':0,'Business travel':1})
df.head()
# Out:
#    Gender  Customer Type  Age  Type of Travel     Class  Flight Distance  \
# 0       0              0   13               0  Eco Plus              460
# 1       0              1   25               1  Business              235
# 2       1              0   26               1  Business             1142
# 3       1              0   25               1  Business              562
# 4       0              0   61               1  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       3              1  ...                       5
# 1                       3              3  ...                       1
# 2                       2              2  ...                       5
# 3                       5              5  ...                       2
# 4                       3              3  ...                       3
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
#
#    Arrival Delay in Minutes  satisfaction
# 0                      18.0             0
# 1                       6.0             0
# 2                       0.0             1
# 3                       9.0             0
# 4                       0.0             1
#
# [5 rows x 23 columns]

# %%
#Encoding class
df["Class"].unique()
# Out:
# array(['Eco Plus', 'Business', 'Eco'], dtype=object)

# %%
df["Class"] = df["Class"].map({"Eco Plus":0,"Business":1,"Eco":2})
df.head()
# Out:
#    Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0       0              0   13               0      0              460
# 1       0              1   25               1      1              235
# 2       1              0   26               1      1             1142
# 3       1              0   25               1      1              562
# 4       0              0   61               1      1              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       3              1  ...                       5
# 1                       3              3  ...                       1
# 2                       2              2  ...                       5
# 3                       5              5  ...                       2
# 4                       3              3  ...                       3
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
#
#    Arrival Delay in Minutes  satisfaction
# 0                      18.0             0
# 1                       6.0             0
# 2                       0.0             1
# 3                       9.0             0
# 4                       0.0             1
#
# [5 rows x 23 columns]

# %%
df.dtypes
# Out:
# Gender                                 int64
# Customer Type                          int64
# Age                                    int64
# Type of Travel                         int64
# Class                                  int64
# Flight Distance                        int64
# Inflight wifi service                  int64
# Departure/Arrival time convenient      int64
# Ease of Online booking                 int64
# Gate location                          int64
# Food and drink                         int64
# Online boarding                        int64
# Seat comfort                           int64
# Inflight entertainment                 int64
# On-board service                       int64
# Leg room service                       int64
# Baggage handling                       int64
# Checkin service                        int64
# Inflight service                       int64
# Cleanliness                            int64
# Departure Delay in Minutes             int64
# Arrival Delay in Minutes             float64
# satisfaction                           int64
# dtype: object

# %% [markdown]
# <h4>All the Categorical Features are encoded</h4>

# %% [markdown]
# <h4>Filling Null values in "Arrival Delay in Minutes" Feature, with the Median as the data is Positively Skewed</h4>

# %%
df.fillna(np.nanmedian(df["Arrival Delay in Minutes"]),inplace = True)

# %%
df.isna().sum()
# Out:
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# satisfaction                         0
# dtype: int64

# %% [markdown]
# <h3>Removing Outliers with the help of Box-Plots</h3>

# %%
sns.set_context("paper", font_scale=1.25)
sns.boxplot(df["Age"])
# Out:
# /home/meghadharsan/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
sns.boxplot(df["Flight Distance"])
# Out:
# /home/meghadharsan/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Flight Distance'>

# %%
sample = df[(df["Flight Distance"]>0)&(df["Flight Distance"]<3000)]
sns.boxplot(sample['Flight Distance'])
# Out:
# /home/meghadharsan/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Flight Distance'>

# %%
df = df[(df["Flight Distance"]>0)&(df["Flight Distance"]<3000)]
sns.boxplot(df['Flight Distance'])
# Out:
# /home/meghadharsan/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Flight Distance'>

# %%
#Number of instances has reduced
df.shape
# Out:
# (95631, 23)

# %%
sns.boxplot(df["Inflight wifi service"])
# Out:
# /home/meghadharsan/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Inflight wifi service'>

# %%
sns.boxplot(df["Departure/Arrival time convenient"])
# Out:
# /home/meghadharsan/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Departure/Arrival time convenient'>

# %%
sns.boxplot(df["Ease of Online booking"])
# Out:
# /home/meghadharsan/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Ease of Online booking'>

# %%
sns.boxplot(df["Gate location"])
# Out:
# /home/meghadharsan/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Gate location'>

# %%
sns.boxplot(df["Food and drink"])
# Out:
# /home/meghadharsan/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Food and drink'>

# %%
plt.figure(figsize=(30,30))
sns.set_context("paper", font_scale=3,rc={"font.size":15})
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
df.drop(columns = ["Arrival Delay in Minutes"],axis = 1,inplace = True)
df.head()
# Out:
# /tmp/ipykernel_44468/498769291.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns = ["Arrival Delay in Minutes"],axis = 1,inplace = True)
#    Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0       0              0   13               0      0              460
# 1       0              1   25               1      1              235
# 2       1              0   26               1      1             1142
# 3       1              0   25               1      1              562
# 4       0              0   61               1      1              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Seat comfort  \
# 0                       3              1  ...             5
# 1                       3              3  ...             1
# 2                       2              2  ...             5
# 3                       5              5  ...             2
# 4                       3              3  ...             5
#
#    Inflight entertainment  On-board service  Leg room service  \
# 0                       5                 4                 3
# 1                       1                 1                 5
# 2                       5                 4                 3
# 3                       2                 2                 5
# 4                       3                 3                 4
#
#    Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 0                 4                4                 5            5
# 1                 3                1                 4            1
# 2                 4                4                 4            5
# 3                 3                1                 4            2
# 4                 4                3                 3            3
#
#    Departure Delay in Minutes  satisfaction
# 0                          25             0
# 1                           1             0
# 2                           0             1
# 3                          11             0
# 4                           0             1
#
# [5 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'satisfaction'],
#       dtype='object')

# %% [markdown]
# <h1>Models</h1>

# %%
X = df.drop(columns = ["satisfaction"],axis = 1)
y = df["satisfaction"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state = 0,shuffle = True)

# %% [markdown]
# <h3>XGBoost</h3>

# %%
from xgboost import XGBClassifier
model = XGBClassifier()
model.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_bin=256, max_cat_threshold=64, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9600970386481512

# %% [markdown]
# ## Accuracy : 0.96

# %% [markdown]
# <h3>CATBoost</h3>

# %%
import catboost
cb = catboost.CatBoostClassifier()
cb.fit(X_train,y_train)
# Out:
# Learning rate set to 0.06387
# 0:	learn: 0.6066636	total: 76.5ms	remaining: 1m 16s
# 1:	learn: 0.5354462	total: 83.1ms	remaining: 41.5s
# 2:	learn: 0.4544074	total: 94.3ms	remaining: 31.3s
# 3:	learn: 0.4002376	total: 101ms	remaining: 25.1s
# 4:	learn: 0.3668532	total: 110ms	remaining: 21.9s
# 5:	learn: 0.3374631	total: 116ms	remaining: 19.2s
# 6:	learn: 0.3167502	total: 124ms	remaining: 17.5s
# 7:	learn: 0.2992852	total: 130ms	remaining: 16.2s
# 8:	learn: 0.2826412	total: 139ms	remaining: 15.4s
# 9:	learn: 0.2700254	total: 147ms	remaining: 14.6s
# 10:	learn: 0.2579715	total: 157ms	remaining: 14.1s
# 11:	learn: 0.2443212	total: 163ms	remaining: 13.4s
# 12:	learn: 0.2328912	total: 169ms	remaining: 12.8s
# 13:	learn: 0.2256984	total: 177ms	remaining: 12.4s
# 14:	learn: 0.2144449	total: 183ms	remaining: 12s
# 15:	learn: 0.2093878	total: 192ms	remaining: 11.8s
# 16:	learn: 0.2044216	total: 198ms	remaining: 11.4s
# 17:	learn: 0.1976798	total: 205ms	remaining: 11.2s
# 18:	learn: 0.1923557	total: 212ms	remaining: 10.9s
# 19:	learn: 0.1872472	total: 217ms	remaining: 10.7s
# 20:	learn: 0.1846917	total: 225ms	remaining: 10.5s
# 21:	learn: 0.1808240	total: 231ms	remaining: 10.3s
# 22:	learn: 0.1766084	total: 238ms	remaining: 10.1s
# 23:	learn: 0.1739594	total: 243ms	remaining: 9.9s
# 24:	learn: 0.1716267	total: 249ms	remaining: 9.73s
# 25:	learn: 0.1689066	total: 256ms	remaining: 9.61s
# 26:	learn: 0.1654688	total: 262ms	remaining: 9.46s
# 27:	learn: 0.1633029	total: 270ms	remaining: 9.37s
# 28:	learn: 0.1607612	total: 276ms	remaining: 9.24s
# 29:	learn: 0.1593150	total: 282ms	remaining: 9.11s
# 30:	learn: 0.1582960	total: 289ms	remaining: 9.05s
# 31:	learn: 0.1569377	total: 295ms	remaining: 8.94s
# 32:	learn: 0.1560777	total: 303ms	remaining: 8.88s
# 33:	learn: 0.1545457	total: 309ms	remaining: 8.78s
# 34:	learn: 0.1529108	total: 315ms	remaining: 8.69s
# 35:	learn: 0.1518567	total: 322ms	remaining: 8.63s
# 36:	learn: 0.1510382	total: 328ms	remaining: 8.54s
# 37:	learn: 0.1500827	total: 335ms	remaining: 8.48s
# 38:	learn: 0.1490599	total: 340ms	remaining: 8.38s
# 39:	learn: 0.1481760	total: 345ms	remaining: 8.29s
# 40:	learn: 0.1475598	total: 352ms	remaining: 8.23s
# 41:	learn: 0.1465369	total: 357ms	remaining: 8.14s
# 42:	learn: 0.1457868	total: 362ms	remaining: 8.05s
# 43:	learn: 0.1448289	total: 369ms	remaining: 8.01s
# 44:	learn: 0.1436158	total: 375ms	remaining: 7.95s
# 45:	learn: 0.1426038	total: 380ms	remaining: 7.88s
# 46:	learn: 0.1411235	total: 387ms	remaining: 7.84s
# 47:	learn: 0.1403318	total: 393ms	remaining: 7.8s
# 48:	learn: 0.1398391	total: 404ms	remaining: 7.84s
# 49:	learn: 0.1393673	total: 413ms	remaining: 7.85s
# 50:	learn: 0.1382788	total: 421ms	remaining: 7.82s
# 51:	learn: 0.1377820	total: 426ms	remaining: 7.77s
# 52:	learn: 0.1371849	total: 433ms	remaining: 7.74s
# 53:	learn: 0.1366211	total: 439ms	remaining: 7.68s
# 54:	learn: 0.1363587	total: 444ms	remaining: 7.63s
# 55:	learn: 0.1360713	total: 451ms	remaining: 7.6s
# 56:	learn: 0.1357566	total: 456ms	remaining: 7.55s
# 57:	learn: 0.1352741	total: 462ms	remaining: 7.5s
# 58:	learn: 0.1338149	total: 469ms	remaining: 7.49s
# 59:	learn: 0.1333254	total: 475ms	remaining: 7.44s
# 60:	learn: 0.1327999	total: 482ms	remaining: 7.42s
# 61:	learn: 0.1325178	total: 488ms	remaining: 7.38s
# 62:	learn: 0.1320427	total: 493ms	remaining: 7.33s
# 63:	learn: 0.1314319	total: 500ms	remaining: 7.32s
# 64:	learn: 0.1312127	total: 506ms	remaining: 7.27s
# 65:	learn: 0.1306950	total: 511ms	remaining: 7.24s
# 66:	learn: 0.1304147	total: 517ms	remaining: 7.21s
# 67:	learn: 0.1299936	total: 523ms	remaining: 7.17s
# 68:	learn: 0.1293303	total: 529ms	remaining: 7.14s
# 69:	learn: 0.1290018	total: 535ms	remaining: 7.11s
# 70:	learn: 0.1281831	total: 541ms	remaining: 7.07s
# 71:	learn: 0.1278187	total: 547ms	remaining: 7.05s
# 72:	learn: 0.1273812	total: 553ms	remaining: 7.02s
# 73:	learn: 0.1268652	total: 558ms	remaining: 6.98s
# 74:	learn: 0.1265851	total: 564ms	remaining: 6.96s
# 75:	learn: 0.1261795	total: 570ms	remaining: 6.93s
# 76:	learn: 0.1257069	total: 575ms	remaining: 6.9s
# 77:	learn: 0.1254849	total: 582ms	remaining: 6.87s
# 78:	learn: 0.1248334	total: 587ms	remaining: 6.84s
# 79:	learn: 0.1245949	total: 593ms	remaining: 6.82s
# 80:	learn: 0.1240057	total: 601ms	remaining: 6.82s
# 81:	learn: 0.1236614	total: 608ms	remaining: 6.8s
# 82:	learn: 0.1234187	total: 615ms	remaining: 6.79s
# 83:	learn: 0.1229391	total: 621ms	remaining: 6.77s
# 84:	learn: 0.1223325	total: 626ms	remaining: 6.74s
# 85:	learn: 0.1219955	total: 633ms	remaining: 6.73s
# 86:	learn: 0.1217401	total: 638ms	remaining: 6.7s
# 87:	learn: 0.1214700	total: 645ms	remaining: 6.68s
# 88:	learn: 0.1211618	total: 650ms	remaining: 6.65s
# 89:	learn: 0.1209154	total: 655ms	remaining: 6.62s
# 90:	learn: 0.1203965	total: 661ms	remaining: 6.6s
# 91:	learn: 0.1199213	total: 666ms	remaining: 6.58s
# 92:	learn: 0.1197401	total: 671ms	remaining: 6.54s
# 93:	learn: 0.1193972	total: 677ms	remaining: 6.53s
# 94:	learn: 0.1190361	total: 683ms	remaining: 6.5s
# 95:	learn: 0.1189268	total: 687ms	remaining: 6.47s
# 96:	learn: 0.1187456	total: 694ms	remaining: 6.46s
# 97:	learn: 0.1184268	total: 699ms	remaining: 6.43s
# 98:	learn: 0.1181426	total: 704ms	remaining: 6.41s
# 99:	learn: 0.1179696	total: 710ms	remaining: 6.39s
# 100:	learn: 0.1177969	total: 715ms	remaining: 6.36s
# 101:	learn: 0.1175811	total: 720ms	remaining: 6.34s
# 102:	learn: 0.1174522	total: 726ms	remaining: 6.32s
# 103:	learn: 0.1171208	total: 732ms	remaining: 6.3s
# 104:	learn: 0.1169231	total: 738ms	remaining: 6.29s
# 105:	learn: 0.1167790	total: 744ms	remaining: 6.28s
# 106:	learn: 0.1165109	total: 749ms	remaining: 6.25s
# 107:	learn: 0.1160467	total: 754ms	remaining: 6.23s
# 108:	learn: 0.1159789	total: 760ms	remaining: 6.22s
# 109:	learn: 0.1157686	total: 765ms	remaining: 6.19s
# 110:	learn: 0.1153294	total: 771ms	remaining: 6.17s
# 111:	learn: 0.1150430	total: 777ms	remaining: 6.16s
# 112:	learn: 0.1147922	total: 783ms	remaining: 6.14s
# 113:	learn: 0.1145874	total: 788ms	remaining: 6.13s
# 114:	learn: 0.1144057	total: 796ms	remaining: 6.13s
# 115:	learn: 0.1140640	total: 802ms	remaining: 6.11s
# 116:	learn: 0.1139269	total: 809ms	remaining: 6.11s
# 117:	learn: 0.1137834	total: 815ms	remaining: 6.09s
# 118:	learn: 0.1135538	total: 821ms	remaining: 6.08s
# 119:	learn: 0.1133160	total: 828ms	remaining: 6.07s
# 120:	learn: 0.1130468	total: 834ms	remaining: 6.06s
# 121:	learn: 0.1126691	total: 842ms	remaining: 6.06s
# 122:	learn: 0.1124257	total: 849ms	remaining: 6.05s
# 123:	learn: 0.1123109	total: 854ms	remaining: 6.04s
# 124:	learn: 0.1122323	total: 862ms	remaining: 6.04s
# 125:	learn: 0.1120778	total: 868ms	remaining: 6.02s
# 126:	learn: 0.1118148	total: 876ms	remaining: 6.02s
# 127:	learn: 0.1117408	total: 882ms	remaining: 6.01s
# 128:	learn: 0.1116001	total: 890ms	remaining: 6.01s
# 129:	learn: 0.1114678	total: 897ms	remaining: 6s
# 130:	learn: 0.1112953	total: 903ms	remaining: 5.99s
# 131:	learn: 0.1109008	total: 912ms	remaining: 6s
# 132:	learn: 0.1103745	total: 919ms	remaining: 5.99s
# 133:	learn: 0.1102715	total: 927ms	remaining: 5.99s
# 134:	learn: 0.1099467	total: 933ms	remaining: 5.98s
# 135:	learn: 0.1097970	total: 942ms	remaining: 5.98s
# 136:	learn: 0.1096099	total: 948ms	remaining: 5.97s
# 137:	learn: 0.1095673	total: 954ms	remaining: 5.96s
# 138:	learn: 0.1093508	total: 962ms	remaining: 5.96s
# 139:	learn: 0.1090802	total: 968ms	remaining: 5.94s
# 140:	learn: 0.1089518	total: 977ms	remaining: 5.95s
# 141:	learn: 0.1087442	total: 986ms	remaining: 5.96s
# 142:	learn: 0.1085464	total: 996ms	remaining: 5.97s
# 143:	learn: 0.1082687	total: 1s	remaining: 5.95s
# 144:	learn: 0.1080259	total: 1.01s	remaining: 5.96s
# 145:	learn: 0.1078922	total: 1.02s	remaining: 5.95s
# 146:	learn: 0.1076519	total: 1.03s	remaining: 5.96s
# 147:	learn: 0.1074265	total: 1.03s	remaining: 5.94s
# 148:	learn: 0.1072208	total: 1.04s	remaining: 5.95s
# 149:	learn: 0.1070437	total: 1.05s	remaining: 5.94s
# 150:	learn: 0.1069523	total: 1.06s	remaining: 5.95s
# 151:	learn: 0.1068970	total: 1.07s	remaining: 5.96s
# 152:	learn: 0.1066134	total: 1.08s	remaining: 5.96s
# 153:	learn: 0.1063043	total: 1.08s	remaining: 5.94s
# 154:	learn: 0.1061603	total: 1.09s	remaining: 5.94s
# 155:	learn: 0.1060781	total: 1.09s	remaining: 5.92s
# 156:	learn: 0.1059766	total: 1.1s	remaining: 5.9s
# 157:	learn: 0.1058624	total: 1.11s	remaining: 5.9s
# 158:	learn: 0.1055680	total: 1.11s	remaining: 5.89s
# 159:	learn: 0.1053033	total: 1.12s	remaining: 5.89s
# 160:	learn: 0.1051615	total: 1.13s	remaining: 5.87s
# 161:	learn: 0.1049620	total: 1.13s	remaining: 5.85s
# 162:	learn: 0.1048824	total: 1.14s	remaining: 5.86s
# 163:	learn: 0.1047233	total: 1.15s	remaining: 5.84s
# 164:	learn: 0.1045628	total: 1.15s	remaining: 5.84s
# 165:	learn: 0.1045215	total: 1.16s	remaining: 5.83s
# 166:	learn: 0.1044277	total: 1.17s	remaining: 5.84s
# 167:	learn: 0.1043080	total: 1.18s	remaining: 5.84s
# 168:	learn: 0.1041405	total: 1.19s	remaining: 5.85s
# 169:	learn: 0.1039979	total: 1.2s	remaining: 5.84s
# 170:	learn: 0.1038522	total: 1.2s	remaining: 5.83s
# 171:	learn: 0.1033058	total: 1.21s	remaining: 5.82s
# 172:	learn: 0.1031434	total: 1.22s	remaining: 5.82s
# 173:	learn: 0.1027332	total: 1.22s	remaining: 5.81s
# 174:	learn: 0.1024713	total: 1.23s	remaining: 5.79s
# 175:	learn: 0.1023906	total: 1.24s	remaining: 5.79s
# 176:	learn: 0.1022461	total: 1.24s	remaining: 5.78s
# 177:	learn: 0.1021580	total: 1.25s	remaining: 5.76s
# 178:	learn: 0.1020688	total: 1.25s	remaining: 5.75s
# 179:	learn: 0.1018663	total: 1.26s	remaining: 5.74s
# 180:	learn: 0.1016702	total: 1.26s	remaining: 5.72s
# 181:	learn: 0.1015250	total: 1.27s	remaining: 5.71s
# 182:	learn: 0.1012935	total: 1.28s	remaining: 5.7s
# 183:	learn: 0.1011947	total: 1.28s	remaining: 5.69s
# 184:	learn: 0.1010537	total: 1.29s	remaining: 5.67s
# 185:	learn: 0.1009625	total: 1.29s	remaining: 5.66s
# 186:	learn: 0.1007996	total: 1.3s	remaining: 5.65s
# 187:	learn: 0.1007187	total: 1.3s	remaining: 5.63s
# 188:	learn: 0.1005691	total: 1.31s	remaining: 5.62s
# 189:	learn: 0.1004998	total: 1.31s	remaining: 5.61s
# 190:	learn: 0.1003562	total: 1.32s	remaining: 5.59s
# 191:	learn: 0.1002703	total: 1.33s	remaining: 5.58s
# 192:	learn: 0.1000780	total: 1.33s	remaining: 5.57s
# 193:	learn: 0.1000373	total: 1.34s	remaining: 5.55s
# 194:	learn: 0.0998827	total: 1.34s	remaining: 5.54s
# 195:	learn: 0.0997748	total: 1.35s	remaining: 5.53s
# 196:	learn: 0.0997264	total: 1.35s	remaining: 5.52s
# 197:	learn: 0.0996494	total: 1.36s	remaining: 5.5s
# 198:	learn: 0.0995471	total: 1.36s	remaining: 5.5s
# 199:	learn: 0.0993861	total: 1.37s	remaining: 5.48s
# 200:	learn: 0.0993410	total: 1.38s	remaining: 5.47s
# 201:	learn: 0.0992653	total: 1.38s	remaining: 5.46s
# 202:	learn: 0.0992102	total: 1.39s	remaining: 5.45s
# 203:	learn: 0.0990783	total: 1.4s	remaining: 5.45s
# 204:	learn: 0.0989601	total: 1.4s	remaining: 5.44s
# 205:	learn: 0.0987392	total: 1.41s	remaining: 5.43s
# 206:	learn: 0.0986677	total: 1.42s	remaining: 5.42s
# 207:	learn: 0.0984935	total: 1.42s	remaining: 5.41s
# 208:	learn: 0.0984511	total: 1.43s	remaining: 5.4s
# 209:	learn: 0.0983569	total: 1.43s	remaining: 5.39s
# 210:	learn: 0.0983225	total: 1.44s	remaining: 5.38s
# 211:	learn: 0.0980768	total: 1.44s	remaining: 5.37s
# 212:	learn: 0.0979051	total: 1.45s	remaining: 5.36s
# 213:	learn: 0.0978704	total: 1.46s	remaining: 5.35s
# 214:	learn: 0.0977948	total: 1.46s	remaining: 5.34s
# 215:	learn: 0.0977233	total: 1.47s	remaining: 5.33s
# 216:	learn: 0.0976261	total: 1.47s	remaining: 5.32s
# 217:	learn: 0.0975886	total: 1.48s	remaining: 5.31s
# 218:	learn: 0.0975332	total: 1.49s	remaining: 5.3s
# 219:	learn: 0.0974351	total: 1.49s	remaining: 5.28s
# 220:	learn: 0.0973255	total: 1.5s	remaining: 5.27s
# 221:	learn: 0.0971159	total: 1.5s	remaining: 5.26s
# 222:	learn: 0.0969961	total: 1.51s	remaining: 5.25s
# 223:	learn: 0.0969735	total: 1.51s	remaining: 5.24s
# 224:	learn: 0.0968452	total: 1.52s	remaining: 5.23s
# 225:	learn: 0.0968277	total: 1.52s	remaining: 5.22s
# 226:	learn: 0.0966862	total: 1.53s	remaining: 5.21s
# 227:	learn: 0.0966620	total: 1.53s	remaining: 5.2s
# 228:	learn: 0.0965484	total: 1.54s	remaining: 5.19s
# 229:	learn: 0.0964262	total: 1.55s	remaining: 5.18s
# 230:	learn: 0.0963328	total: 1.55s	remaining: 5.17s
# 231:	learn: 0.0962541	total: 1.56s	remaining: 5.16s
# 232:	learn: 0.0961927	total: 1.56s	remaining: 5.15s
# 233:	learn: 0.0960896	total: 1.57s	remaining: 5.14s
# 234:	learn: 0.0960084	total: 1.58s	remaining: 5.13s
# 235:	learn: 0.0956482	total: 1.58s	remaining: 5.12s
# 236:	learn: 0.0955626	total: 1.59s	remaining: 5.11s
# 237:	learn: 0.0954017	total: 1.59s	remaining: 5.1s
# 238:	learn: 0.0953286	total: 1.6s	remaining: 5.1s
# 239:	learn: 0.0952734	total: 1.61s	remaining: 5.09s
# 240:	learn: 0.0951936	total: 1.61s	remaining: 5.08s
# 241:	learn: 0.0950979	total: 1.62s	remaining: 5.08s
# 242:	learn: 0.0949724	total: 1.63s	remaining: 5.07s
# 243:	learn: 0.0949204	total: 1.63s	remaining: 5.06s
# 244:	learn: 0.0948780	total: 1.64s	remaining: 5.05s
# 245:	learn: 0.0948070	total: 1.65s	remaining: 5.04s
# 246:	learn: 0.0947386	total: 1.65s	remaining: 5.03s
# 247:	learn: 0.0946477	total: 1.66s	remaining: 5.02s
# 248:	learn: 0.0946279	total: 1.66s	remaining: 5.01s
# 249:	learn: 0.0944712	total: 1.67s	remaining: 5s
# 250:	learn: 0.0943908	total: 1.67s	remaining: 4.99s
# 251:	learn: 0.0942655	total: 1.68s	remaining: 4.98s
# 252:	learn: 0.0942104	total: 1.68s	remaining: 4.97s
# 253:	learn: 0.0941250	total: 1.69s	remaining: 4.96s
# 254:	learn: 0.0940539	total: 1.69s	remaining: 4.95s
# 255:	learn: 0.0939733	total: 1.7s	remaining: 4.94s
# 256:	learn: 0.0938787	total: 1.7s	remaining: 4.93s
# 257:	learn: 0.0937791	total: 1.71s	remaining: 4.92s
# 258:	learn: 0.0937464	total: 1.72s	remaining: 4.91s
# 259:	learn: 0.0937056	total: 1.72s	remaining: 4.9s
# 260:	learn: 0.0935892	total: 1.73s	remaining: 4.9s
# 261:	learn: 0.0935077	total: 1.74s	remaining: 4.89s
# 262:	learn: 0.0934286	total: 1.74s	remaining: 4.88s
# 263:	learn: 0.0932781	total: 1.75s	remaining: 4.87s
# 264:	learn: 0.0931780	total: 1.75s	remaining: 4.86s
# 265:	learn: 0.0930325	total: 1.76s	remaining: 4.85s
# 266:	learn: 0.0929536	total: 1.76s	remaining: 4.84s
# 267:	learn: 0.0928824	total: 1.77s	remaining: 4.83s
# 268:	learn: 0.0927920	total: 1.78s	remaining: 4.83s
# 269:	learn: 0.0927062	total: 1.78s	remaining: 4.82s
# 270:	learn: 0.0926443	total: 1.79s	remaining: 4.81s
# 271:	learn: 0.0925414	total: 1.79s	remaining: 4.8s
# 272:	learn: 0.0924838	total: 1.8s	remaining: 4.79s
# 273:	learn: 0.0924604	total: 1.81s	remaining: 4.79s
# 274:	learn: 0.0923952	total: 1.82s	remaining: 4.79s
# 275:	learn: 0.0922470	total: 1.82s	remaining: 4.78s
# 276:	learn: 0.0921838	total: 1.83s	remaining: 4.77s
# 277:	learn: 0.0920797	total: 1.83s	remaining: 4.76s
# 278:	learn: 0.0920231	total: 1.84s	remaining: 4.75s
# 279:	learn: 0.0918898	total: 1.84s	remaining: 4.74s
# 280:	learn: 0.0918043	total: 1.85s	remaining: 4.73s
# 281:	learn: 0.0917025	total: 1.86s	remaining: 4.73s
# 282:	learn: 0.0916437	total: 1.86s	remaining: 4.72s
# 283:	learn: 0.0916262	total: 1.87s	remaining: 4.71s
# 284:	learn: 0.0915844	total: 1.87s	remaining: 4.7s
# 285:	learn: 0.0915264	total: 1.88s	remaining: 4.7s
# 286:	learn: 0.0915174	total: 1.89s	remaining: 4.69s
# 287:	learn: 0.0914433	total: 1.89s	remaining: 4.68s
# 288:	learn: 0.0914087	total: 1.9s	remaining: 4.67s
# 289:	learn: 0.0913278	total: 1.9s	remaining: 4.66s
# 290:	learn: 0.0912753	total: 1.91s	remaining: 4.65s
# 291:	learn: 0.0912448	total: 1.91s	remaining: 4.64s
# 292:	learn: 0.0911458	total: 1.92s	remaining: 4.63s
# 293:	learn: 0.0910695	total: 1.93s	remaining: 4.63s
# 294:	learn: 0.0909868	total: 1.93s	remaining: 4.62s
# 295:	learn: 0.0909494	total: 1.94s	remaining: 4.61s
# 296:	learn: 0.0908703	total: 1.94s	remaining: 4.6s
# 297:	learn: 0.0908332	total: 1.95s	remaining: 4.59s
# 298:	learn: 0.0907829	total: 1.95s	remaining: 4.58s
# 299:	learn: 0.0907194	total: 1.96s	remaining: 4.57s
# 300:	learn: 0.0906386	total: 1.97s	remaining: 4.57s
# 301:	learn: 0.0905576	total: 1.97s	remaining: 4.56s
# 302:	learn: 0.0904832	total: 1.98s	remaining: 4.55s
# 303:	learn: 0.0904421	total: 1.98s	remaining: 4.54s
# 304:	learn: 0.0903870	total: 1.99s	remaining: 4.53s
# 305:	learn: 0.0903016	total: 1.99s	remaining: 4.52s
# 306:	learn: 0.0902450	total: 2s	remaining: 4.51s
# 307:	learn: 0.0901906	total: 2s	remaining: 4.51s
# 308:	learn: 0.0900991	total: 2.01s	remaining: 4.5s
# 309:	learn: 0.0900812	total: 2.02s	remaining: 4.49s
# 310:	learn: 0.0900449	total: 2.02s	remaining: 4.48s
# 311:	learn: 0.0900124	total: 2.03s	remaining: 4.47s
# 312:	learn: 0.0899659	total: 2.04s	remaining: 4.47s
# 313:	learn: 0.0899361	total: 2.04s	remaining: 4.46s
# 314:	learn: 0.0898943	total: 2.04s	remaining: 4.45s
# 315:	learn: 0.0897997	total: 2.05s	remaining: 4.44s
# 316:	learn: 0.0896756	total: 2.06s	remaining: 4.43s
# 317:	learn: 0.0895029	total: 2.06s	remaining: 4.42s
# 318:	learn: 0.0894890	total: 2.07s	remaining: 4.42s
# 319:	learn: 0.0894175	total: 2.08s	remaining: 4.41s
# 320:	learn: 0.0893795	total: 2.08s	remaining: 4.4s
# 321:	learn: 0.0892981	total: 2.09s	remaining: 4.4s
# 322:	learn: 0.0892541	total: 2.1s	remaining: 4.39s
# 323:	learn: 0.0891593	total: 2.1s	remaining: 4.39s
# 324:	learn: 0.0889648	total: 2.11s	remaining: 4.38s
# 325:	learn: 0.0888977	total: 2.12s	remaining: 4.38s
# 326:	learn: 0.0888273	total: 2.12s	remaining: 4.37s
# 327:	learn: 0.0887778	total: 2.13s	remaining: 4.37s
# 328:	learn: 0.0887308	total: 2.14s	remaining: 4.36s
# 329:	learn: 0.0886604	total: 2.14s	remaining: 4.35s
# 330:	learn: 0.0885925	total: 2.15s	remaining: 4.35s
# 331:	learn: 0.0885004	total: 2.16s	remaining: 4.34s
# 332:	learn: 0.0884747	total: 2.16s	remaining: 4.33s
# 333:	learn: 0.0884452	total: 2.17s	remaining: 4.33s
# 334:	learn: 0.0884279	total: 2.17s	remaining: 4.32s
# 335:	learn: 0.0884153	total: 2.18s	remaining: 4.31s
# 336:	learn: 0.0883740	total: 2.19s	remaining: 4.3s
# 337:	learn: 0.0883136	total: 2.19s	remaining: 4.3s
# 338:	learn: 0.0882798	total: 2.2s	remaining: 4.29s
# 339:	learn: 0.0882159	total: 2.21s	remaining: 4.29s
# 340:	learn: 0.0882037	total: 2.21s	remaining: 4.28s
# 341:	learn: 0.0880641	total: 2.22s	remaining: 4.28s
# 342:	learn: 0.0879743	total: 2.23s	remaining: 4.27s
# 343:	learn: 0.0879286	total: 2.23s	remaining: 4.26s
# 344:	learn: 0.0878002	total: 2.24s	remaining: 4.26s
# 345:	learn: 0.0877390	total: 2.25s	remaining: 4.25s
# 346:	learn: 0.0876903	total: 2.25s	remaining: 4.25s
# 347:	learn: 0.0876589	total: 2.26s	remaining: 4.24s
# 348:	learn: 0.0875882	total: 2.27s	remaining: 4.23s
# 349:	learn: 0.0875399	total: 2.28s	remaining: 4.23s
# 350:	learn: 0.0874900	total: 2.28s	remaining: 4.22s
# 351:	learn: 0.0874401	total: 2.29s	remaining: 4.21s
# 352:	learn: 0.0873950	total: 2.3s	remaining: 4.21s
# 353:	learn: 0.0873321	total: 2.3s	remaining: 4.2s
# 354:	learn: 0.0872960	total: 2.31s	remaining: 4.19s
# 355:	learn: 0.0872258	total: 2.32s	remaining: 4.19s
# 356:	learn: 0.0871637	total: 2.32s	remaining: 4.18s
# 357:	learn: 0.0871385	total: 2.33s	remaining: 4.17s
# 358:	learn: 0.0870821	total: 2.33s	remaining: 4.17s
# 359:	learn: 0.0870390	total: 2.34s	remaining: 4.16s
# 360:	learn: 0.0869975	total: 2.35s	remaining: 4.16s
# 361:	learn: 0.0869210	total: 2.35s	remaining: 4.15s
# 362:	learn: 0.0868850	total: 2.36s	remaining: 4.14s
# 363:	learn: 0.0868603	total: 2.37s	remaining: 4.14s
# 364:	learn: 0.0868400	total: 2.37s	remaining: 4.13s
# 365:	learn: 0.0868108	total: 2.38s	remaining: 4.13s
# 366:	learn: 0.0867626	total: 2.39s	remaining: 4.12s
# 367:	learn: 0.0867430	total: 2.39s	remaining: 4.11s
# 368:	learn: 0.0866592	total: 2.4s	remaining: 4.11s
# 369:	learn: 0.0865551	total: 2.41s	remaining: 4.1s
# 370:	learn: 0.0864785	total: 2.42s	remaining: 4.09s
# 371:	learn: 0.0863968	total: 2.42s	remaining: 4.09s
# 372:	learn: 0.0863147	total: 2.43s	remaining: 4.08s
# 373:	learn: 0.0862686	total: 2.44s	remaining: 4.08s
# 374:	learn: 0.0862064	total: 2.44s	remaining: 4.07s
# 375:	learn: 0.0861161	total: 2.45s	remaining: 4.07s
# 376:	learn: 0.0860498	total: 2.46s	remaining: 4.07s
# 377:	learn: 0.0859503	total: 2.47s	remaining: 4.06s
# 378:	learn: 0.0859046	total: 2.47s	remaining: 4.05s
# 379:	learn: 0.0858879	total: 2.48s	remaining: 4.05s
# 380:	learn: 0.0858458	total: 2.49s	remaining: 4.04s
# 381:	learn: 0.0858319	total: 2.49s	remaining: 4.04s
# 382:	learn: 0.0857951	total: 2.5s	remaining: 4.03s
# 383:	learn: 0.0857543	total: 2.5s	remaining: 4.02s
# 384:	learn: 0.0856084	total: 2.51s	remaining: 4.01s
# 385:	learn: 0.0855549	total: 2.52s	remaining: 4s
# 386:	learn: 0.0854934	total: 2.52s	remaining: 4s
# 387:	learn: 0.0854209	total: 2.53s	remaining: 3.99s
# 388:	learn: 0.0853176	total: 2.53s	remaining: 3.98s
# 389:	learn: 0.0851941	total: 2.54s	remaining: 3.97s
# 390:	learn: 0.0851423	total: 2.54s	remaining: 3.96s
# 391:	learn: 0.0850845	total: 2.55s	remaining: 3.96s
# 392:	learn: 0.0850476	total: 2.56s	remaining: 3.95s
# 393:	learn: 0.0849737	total: 2.56s	remaining: 3.94s
# 394:	learn: 0.0849194	total: 2.57s	remaining: 3.93s
# 395:	learn: 0.0848814	total: 2.58s	remaining: 3.93s
# 396:	learn: 0.0848245	total: 2.58s	remaining: 3.92s
# 397:	learn: 0.0847843	total: 2.59s	remaining: 3.91s
# 398:	learn: 0.0847677	total: 2.59s	remaining: 3.9s
# 399:	learn: 0.0847136	total: 2.6s	remaining: 3.9s
# 400:	learn: 0.0846078	total: 2.6s	remaining: 3.89s
# 401:	learn: 0.0845838	total: 2.61s	remaining: 3.88s
# 402:	learn: 0.0844717	total: 2.62s	remaining: 3.88s
# 403:	learn: 0.0843614	total: 2.62s	remaining: 3.87s
# 404:	learn: 0.0843181	total: 2.63s	remaining: 3.86s
# 405:	learn: 0.0842872	total: 2.63s	remaining: 3.85s
# 406:	learn: 0.0842428	total: 2.64s	remaining: 3.84s
# 407:	learn: 0.0842174	total: 2.64s	remaining: 3.84s
# 408:	learn: 0.0841813	total: 2.65s	remaining: 3.83s
# 409:	learn: 0.0841409	total: 2.66s	remaining: 3.82s
# 410:	learn: 0.0840539	total: 2.66s	remaining: 3.81s
# 411:	learn: 0.0840058	total: 2.67s	remaining: 3.81s
# 412:	learn: 0.0839675	total: 2.67s	remaining: 3.8s
# 413:	learn: 0.0839138	total: 2.68s	remaining: 3.79s
# 414:	learn: 0.0838598	total: 2.68s	remaining: 3.78s
# 415:	learn: 0.0838209	total: 2.69s	remaining: 3.78s
# 416:	learn: 0.0837715	total: 2.7s	remaining: 3.77s
# 417:	learn: 0.0837302	total: 2.7s	remaining: 3.76s
# 418:	learn: 0.0836471	total: 2.71s	remaining: 3.75s
# 419:	learn: 0.0835950	total: 2.71s	remaining: 3.75s
# 420:	learn: 0.0835580	total: 2.72s	remaining: 3.74s
# 421:	learn: 0.0835344	total: 2.72s	remaining: 3.73s
# 422:	learn: 0.0834789	total: 2.73s	remaining: 3.72s
# 423:	learn: 0.0834646	total: 2.74s	remaining: 3.72s
# 424:	learn: 0.0834469	total: 2.74s	remaining: 3.71s
# 425:	learn: 0.0834134	total: 2.75s	remaining: 3.7s
# 426:	learn: 0.0833771	total: 2.75s	remaining: 3.69s
# 427:	learn: 0.0833571	total: 2.76s	remaining: 3.68s
# 428:	learn: 0.0833488	total: 2.76s	remaining: 3.67s
# 429:	learn: 0.0833110	total: 2.77s	remaining: 3.67s
# 430:	learn: 0.0832661	total: 2.77s	remaining: 3.66s
# 431:	learn: 0.0832491	total: 2.78s	remaining: 3.65s
# 432:	learn: 0.0832319	total: 2.78s	remaining: 3.65s
# 433:	learn: 0.0831797	total: 2.79s	remaining: 3.64s
# 434:	learn: 0.0831291	total: 2.79s	remaining: 3.63s
# 435:	learn: 0.0830921	total: 2.8s	remaining: 3.62s
# 436:	learn: 0.0830565	total: 2.81s	remaining: 3.62s
# 437:	learn: 0.0830243	total: 2.81s	remaining: 3.61s
# 438:	learn: 0.0829824	total: 2.82s	remaining: 3.6s
# 439:	learn: 0.0829790	total: 2.82s	remaining: 3.59s
# 440:	learn: 0.0829523	total: 2.83s	remaining: 3.59s
# 441:	learn: 0.0829366	total: 2.84s	remaining: 3.58s
# 442:	learn: 0.0828736	total: 2.84s	remaining: 3.57s
# 443:	learn: 0.0828000	total: 2.85s	remaining: 3.56s
# 444:	learn: 0.0827724	total: 2.85s	remaining: 3.56s
# 445:	learn: 0.0827201	total: 2.86s	remaining: 3.55s
# 446:	learn: 0.0826827	total: 2.87s	remaining: 3.54s
# 447:	learn: 0.0826456	total: 2.87s	remaining: 3.54s
# 448:	learn: 0.0826124	total: 2.88s	remaining: 3.53s
# 449:	learn: 0.0825704	total: 2.88s	remaining: 3.52s
# 450:	learn: 0.0825531	total: 2.89s	remaining: 3.52s
# 451:	learn: 0.0825072	total: 2.9s	remaining: 3.51s
# 452:	learn: 0.0824929	total: 2.9s	remaining: 3.5s
# 453:	learn: 0.0824766	total: 2.91s	remaining: 3.5s
# 454:	learn: 0.0824328	total: 2.91s	remaining: 3.49s
# 455:	learn: 0.0823925	total: 2.92s	remaining: 3.48s
# 456:	learn: 0.0823636	total: 2.92s	remaining: 3.47s
# 457:	learn: 0.0823413	total: 2.93s	remaining: 3.47s
# 458:	learn: 0.0822960	total: 2.94s	remaining: 3.46s
# 459:	learn: 0.0822687	total: 2.94s	remaining: 3.45s
# 460:	learn: 0.0822542	total: 2.94s	remaining: 3.44s
# 461:	learn: 0.0822276	total: 2.95s	remaining: 3.44s
# 462:	learn: 0.0821772	total: 2.96s	remaining: 3.43s
# 463:	learn: 0.0821325	total: 2.96s	remaining: 3.42s
# 464:	learn: 0.0820900	total: 2.97s	remaining: 3.41s
# 465:	learn: 0.0820494	total: 2.97s	remaining: 3.41s
# 466:	learn: 0.0820159	total: 2.98s	remaining: 3.4s
# 467:	learn: 0.0819701	total: 2.98s	remaining: 3.39s
# 468:	learn: 0.0819408	total: 2.99s	remaining: 3.38s
# 469:	learn: 0.0819128	total: 2.99s	remaining: 3.38s
# 470:	learn: 0.0818626	total: 3s	remaining: 3.37s
# 471:	learn: 0.0818214	total: 3.01s	remaining: 3.36s
# 472:	learn: 0.0817700	total: 3.01s	remaining: 3.36s
# 473:	learn: 0.0817384	total: 3.02s	remaining: 3.35s
# 474:	learn: 0.0817256	total: 3.02s	remaining: 3.34s
# 475:	learn: 0.0816931	total: 3.03s	remaining: 3.34s
# 476:	learn: 0.0816696	total: 3.04s	remaining: 3.33s
# 477:	learn: 0.0816271	total: 3.04s	remaining: 3.32s
# 478:	learn: 0.0815505	total: 3.05s	remaining: 3.31s
# 479:	learn: 0.0814719	total: 3.05s	remaining: 3.31s
# 480:	learn: 0.0814352	total: 3.06s	remaining: 3.3s
# 481:	learn: 0.0813894	total: 3.06s	remaining: 3.29s
# 482:	learn: 0.0813346	total: 3.07s	remaining: 3.28s
# 483:	learn: 0.0813079	total: 3.07s	remaining: 3.28s
# 484:	learn: 0.0812316	total: 3.08s	remaining: 3.27s
# 485:	learn: 0.0811917	total: 3.08s	remaining: 3.26s
# 486:	learn: 0.0811356	total: 3.09s	remaining: 3.25s
# 487:	learn: 0.0810980	total: 3.1s	remaining: 3.25s
# 488:	learn: 0.0810673	total: 3.1s	remaining: 3.24s
# 489:	learn: 0.0810240	total: 3.11s	remaining: 3.23s
# 490:	learn: 0.0809829	total: 3.11s	remaining: 3.23s
# 491:	learn: 0.0809616	total: 3.12s	remaining: 3.22s
# 492:	learn: 0.0808786	total: 3.12s	remaining: 3.21s
# 493:	learn: 0.0808451	total: 3.13s	remaining: 3.21s
# 494:	learn: 0.0808137	total: 3.14s	remaining: 3.2s
# 495:	learn: 0.0807695	total: 3.14s	remaining: 3.19s
# 496:	learn: 0.0807323	total: 3.15s	remaining: 3.18s
# 497:	learn: 0.0806953	total: 3.15s	remaining: 3.18s
# 498:	learn: 0.0806520	total: 3.16s	remaining: 3.17s
# 499:	learn: 0.0806187	total: 3.16s	remaining: 3.16s
# 500:	learn: 0.0805874	total: 3.17s	remaining: 3.15s
# 501:	learn: 0.0805676	total: 3.17s	remaining: 3.15s
# 502:	learn: 0.0805212	total: 3.18s	remaining: 3.14s
# 503:	learn: 0.0804560	total: 3.18s	remaining: 3.13s
# 504:	learn: 0.0804208	total: 3.19s	remaining: 3.13s
# 505:	learn: 0.0803600	total: 3.19s	remaining: 3.12s
# 506:	learn: 0.0803195	total: 3.2s	remaining: 3.11s
# 507:	learn: 0.0802826	total: 3.21s	remaining: 3.11s
# 508:	learn: 0.0802493	total: 3.21s	remaining: 3.1s
# 509:	learn: 0.0802108	total: 3.22s	remaining: 3.09s
# 510:	learn: 0.0801832	total: 3.23s	remaining: 3.09s
# 511:	learn: 0.0801480	total: 3.23s	remaining: 3.08s
# 512:	learn: 0.0801150	total: 3.24s	remaining: 3.08s
# 513:	learn: 0.0800877	total: 3.25s	remaining: 3.07s
# 514:	learn: 0.0800191	total: 3.25s	remaining: 3.06s
# 515:	learn: 0.0799607	total: 3.26s	remaining: 3.06s
# 516:	learn: 0.0799189	total: 3.26s	remaining: 3.05s
# 517:	learn: 0.0798885	total: 3.27s	remaining: 3.04s
# 518:	learn: 0.0798703	total: 3.27s	remaining: 3.03s
# 519:	learn: 0.0798389	total: 3.28s	remaining: 3.03s
# 520:	learn: 0.0798095	total: 3.28s	remaining: 3.02s
# 521:	learn: 0.0797733	total: 3.29s	remaining: 3.01s
# 522:	learn: 0.0797486	total: 3.29s	remaining: 3s
# 523:	learn: 0.0797224	total: 3.3s	remaining: 3s
# 524:	learn: 0.0796924	total: 3.31s	remaining: 2.99s
# 525:	learn: 0.0796736	total: 3.31s	remaining: 2.98s
# 526:	learn: 0.0796216	total: 3.32s	remaining: 2.98s
# 527:	learn: 0.0796146	total: 3.32s	remaining: 2.97s
# 528:	learn: 0.0796020	total: 3.33s	remaining: 2.96s
# 529:	learn: 0.0795914	total: 3.33s	remaining: 2.96s
# 530:	learn: 0.0795742	total: 3.34s	remaining: 2.95s
# 531:	learn: 0.0795438	total: 3.34s	remaining: 2.94s
# 532:	learn: 0.0795108	total: 3.35s	remaining: 2.93s
# 533:	learn: 0.0794701	total: 3.35s	remaining: 2.93s
# 534:	learn: 0.0794112	total: 3.36s	remaining: 2.92s
# 535:	learn: 0.0793713	total: 3.37s	remaining: 2.91s
# 536:	learn: 0.0793412	total: 3.37s	remaining: 2.91s
# 537:	learn: 0.0792964	total: 3.38s	remaining: 2.9s
# 538:	learn: 0.0792674	total: 3.38s	remaining: 2.89s
# 539:	learn: 0.0792343	total: 3.39s	remaining: 2.89s
# 540:	learn: 0.0791994	total: 3.39s	remaining: 2.88s
# 541:	learn: 0.0791699	total: 3.4s	remaining: 2.87s
# 542:	learn: 0.0791291	total: 3.4s	remaining: 2.87s
# 543:	learn: 0.0790979	total: 3.41s	remaining: 2.86s
# 544:	learn: 0.0790593	total: 3.42s	remaining: 2.85s
# 545:	learn: 0.0790351	total: 3.42s	remaining: 2.85s
# 546:	learn: 0.0789982	total: 3.43s	remaining: 2.84s
# 547:	learn: 0.0789657	total: 3.43s	remaining: 2.83s
# 548:	learn: 0.0789321	total: 3.44s	remaining: 2.83s
# 549:	learn: 0.0789135	total: 3.44s	remaining: 2.82s
# 550:	learn: 0.0788768	total: 3.45s	remaining: 2.81s
# 551:	learn: 0.0788600	total: 3.46s	remaining: 2.81s
# 552:	learn: 0.0788423	total: 3.46s	remaining: 2.8s
# 553:	learn: 0.0788165	total: 3.47s	remaining: 2.79s
# 554:	learn: 0.0788079	total: 3.47s	remaining: 2.78s
# 555:	learn: 0.0788028	total: 3.48s	remaining: 2.78s
# 556:	learn: 0.0787744	total: 3.48s	remaining: 2.77s
# 557:	learn: 0.0787487	total: 3.49s	remaining: 2.76s
# 558:	learn: 0.0787030	total: 3.49s	remaining: 2.76s
# 559:	learn: 0.0786409	total: 3.5s	remaining: 2.75s
# 560:	learn: 0.0786247	total: 3.51s	remaining: 2.74s
# 561:	learn: 0.0785957	total: 3.51s	remaining: 2.74s
# 562:	learn: 0.0785793	total: 3.52s	remaining: 2.73s
# 563:	learn: 0.0785343	total: 3.52s	remaining: 2.72s
# 564:	learn: 0.0784917	total: 3.53s	remaining: 2.72s
# 565:	learn: 0.0784307	total: 3.54s	remaining: 2.71s
# 566:	learn: 0.0784037	total: 3.54s	remaining: 2.7s
# 567:	learn: 0.0783733	total: 3.54s	remaining: 2.7s
# 568:	learn: 0.0783501	total: 3.55s	remaining: 2.69s
# 569:	learn: 0.0783126	total: 3.56s	remaining: 2.68s
# 570:	learn: 0.0782951	total: 3.56s	remaining: 2.68s
# 571:	learn: 0.0781168	total: 3.57s	remaining: 2.67s
# 572:	learn: 0.0780869	total: 3.57s	remaining: 2.66s
# 573:	learn: 0.0780691	total: 3.58s	remaining: 2.65s
# 574:	learn: 0.0780269	total: 3.58s	remaining: 2.65s
# 575:	learn: 0.0779968	total: 3.59s	remaining: 2.64s
# 576:	learn: 0.0779128	total: 3.6s	remaining: 2.64s
# 577:	learn: 0.0778877	total: 3.6s	remaining: 2.63s
# 578:	learn: 0.0778548	total: 3.61s	remaining: 2.62s
# 579:	learn: 0.0778302	total: 3.62s	remaining: 2.62s
# 580:	learn: 0.0778103	total: 3.62s	remaining: 2.61s
# 581:	learn: 0.0777945	total: 3.63s	remaining: 2.6s
# 582:	learn: 0.0777488	total: 3.63s	remaining: 2.6s
# 583:	learn: 0.0776987	total: 3.64s	remaining: 2.59s
# 584:	learn: 0.0776673	total: 3.64s	remaining: 2.58s
# 585:	learn: 0.0776296	total: 3.65s	remaining: 2.58s
# 586:	learn: 0.0776098	total: 3.65s	remaining: 2.57s
# 587:	learn: 0.0775832	total: 3.66s	remaining: 2.56s
# 588:	learn: 0.0775516	total: 3.67s	remaining: 2.56s
# 589:	learn: 0.0775179	total: 3.67s	remaining: 2.55s
# 590:	learn: 0.0775007	total: 3.68s	remaining: 2.54s
# 591:	learn: 0.0774711	total: 3.68s	remaining: 2.54s
# 592:	learn: 0.0774436	total: 3.69s	remaining: 2.53s
# 593:	learn: 0.0774030	total: 3.69s	remaining: 2.52s
# 594:	learn: 0.0773803	total: 3.7s	remaining: 2.52s
# 595:	learn: 0.0773443	total: 3.7s	remaining: 2.51s
# 596:	learn: 0.0773040	total: 3.71s	remaining: 2.5s
# 597:	learn: 0.0772846	total: 3.71s	remaining: 2.5s
# 598:	learn: 0.0772379	total: 3.72s	remaining: 2.49s
# 599:	learn: 0.0772007	total: 3.73s	remaining: 2.48s
# 600:	learn: 0.0771630	total: 3.73s	remaining: 2.48s
# 601:	learn: 0.0771510	total: 3.74s	remaining: 2.47s
# 602:	learn: 0.0771360	total: 3.74s	remaining: 2.46s
# 603:	learn: 0.0771190	total: 3.75s	remaining: 2.46s
# 604:	learn: 0.0770941	total: 3.75s	remaining: 2.45s
# 605:	learn: 0.0770850	total: 3.76s	remaining: 2.44s
# 606:	learn: 0.0770658	total: 3.76s	remaining: 2.44s
# 607:	learn: 0.0770613	total: 3.77s	remaining: 2.43s
# 608:	learn: 0.0770275	total: 3.77s	remaining: 2.42s
# 609:	learn: 0.0769910	total: 3.78s	remaining: 2.42s
# 610:	learn: 0.0769704	total: 3.79s	remaining: 2.41s
# 611:	learn: 0.0769442	total: 3.79s	remaining: 2.4s
# 612:	learn: 0.0769065	total: 3.8s	remaining: 2.4s
# 613:	learn: 0.0768676	total: 3.8s	remaining: 2.39s
# 614:	learn: 0.0768192	total: 3.81s	remaining: 2.38s
# 615:	learn: 0.0767950	total: 3.82s	remaining: 2.38s
# 616:	learn: 0.0767004	total: 3.83s	remaining: 2.38s
# 617:	learn: 0.0766764	total: 3.84s	remaining: 2.37s
# 618:	learn: 0.0766402	total: 3.85s	remaining: 2.37s
# 619:	learn: 0.0766132	total: 3.85s	remaining: 2.36s
# 620:	learn: 0.0765865	total: 3.86s	remaining: 2.35s
# 621:	learn: 0.0765285	total: 3.86s	remaining: 2.35s
# 622:	learn: 0.0765003	total: 3.87s	remaining: 2.34s
# 623:	learn: 0.0764482	total: 3.88s	remaining: 2.34s
# 624:	learn: 0.0764180	total: 3.88s	remaining: 2.33s
# 625:	learn: 0.0763993	total: 3.89s	remaining: 2.32s
# 626:	learn: 0.0763794	total: 3.9s	remaining: 2.32s
# 627:	learn: 0.0763414	total: 3.9s	remaining: 2.31s
# 628:	learn: 0.0763166	total: 3.91s	remaining: 2.3s
# 629:	learn: 0.0762944	total: 3.91s	remaining: 2.3s
# 630:	learn: 0.0762730	total: 3.92s	remaining: 2.29s
# 631:	learn: 0.0762389	total: 3.93s	remaining: 2.29s
# 632:	learn: 0.0762140	total: 3.93s	remaining: 2.28s
# 633:	learn: 0.0761881	total: 3.94s	remaining: 2.27s
# 634:	learn: 0.0761625	total: 3.94s	remaining: 2.27s
# 635:	learn: 0.0761376	total: 3.95s	remaining: 2.26s
# 636:	learn: 0.0760759	total: 3.96s	remaining: 2.26s
# 637:	learn: 0.0760338	total: 3.96s	remaining: 2.25s
# 638:	learn: 0.0759939	total: 3.97s	remaining: 2.24s
# 639:	learn: 0.0759888	total: 3.98s	remaining: 2.24s
# 640:	learn: 0.0759618	total: 3.98s	remaining: 2.23s
# 641:	learn: 0.0759248	total: 3.99s	remaining: 2.22s
# 642:	learn: 0.0759054	total: 3.99s	remaining: 2.22s
# 643:	learn: 0.0758964	total: 4s	remaining: 2.21s
# 644:	learn: 0.0758776	total: 4.01s	remaining: 2.21s
# 645:	learn: 0.0758691	total: 4.01s	remaining: 2.2s
# 646:	learn: 0.0758275	total: 4.02s	remaining: 2.19s
# 647:	learn: 0.0758134	total: 4.03s	remaining: 2.19s
# 648:	learn: 0.0757747	total: 4.03s	remaining: 2.18s
# 649:	learn: 0.0757597	total: 4.04s	remaining: 2.17s
# 650:	learn: 0.0757131	total: 4.05s	remaining: 2.17s
# 651:	learn: 0.0756992	total: 4.06s	remaining: 2.17s
# 652:	learn: 0.0756529	total: 4.06s	remaining: 2.16s
# 653:	learn: 0.0756432	total: 4.07s	remaining: 2.15s
# 654:	learn: 0.0756277	total: 4.08s	remaining: 2.15s
# 655:	learn: 0.0756196	total: 4.08s	remaining: 2.14s
# 656:	learn: 0.0756007	total: 4.09s	remaining: 2.13s
# 657:	learn: 0.0755938	total: 4.09s	remaining: 2.13s
# 658:	learn: 0.0755541	total: 4.1s	remaining: 2.12s
# 659:	learn: 0.0755218	total: 4.11s	remaining: 2.12s
# 660:	learn: 0.0754857	total: 4.11s	remaining: 2.11s
# 661:	learn: 0.0754554	total: 4.12s	remaining: 2.1s
# 662:	learn: 0.0753426	total: 4.12s	remaining: 2.1s
# 663:	learn: 0.0753257	total: 4.13s	remaining: 2.09s
# 664:	learn: 0.0752773	total: 4.14s	remaining: 2.09s
# 665:	learn: 0.0752699	total: 4.15s	remaining: 2.08s
# 666:	learn: 0.0752608	total: 4.16s	remaining: 2.07s
# 667:	learn: 0.0752474	total: 4.16s	remaining: 2.07s
# 668:	learn: 0.0752144	total: 4.17s	remaining: 2.06s
# 669:	learn: 0.0751724	total: 4.17s	remaining: 2.06s
# 670:	learn: 0.0751349	total: 4.18s	remaining: 2.05s
# 671:	learn: 0.0750878	total: 4.18s	remaining: 2.04s
# 672:	learn: 0.0750267	total: 4.19s	remaining: 2.04s
# 673:	learn: 0.0750079	total: 4.21s	remaining: 2.03s
# 674:	learn: 0.0750006	total: 4.21s	remaining: 2.03s
# 675:	learn: 0.0749754	total: 4.22s	remaining: 2.02s
# 676:	learn: 0.0749701	total: 4.23s	remaining: 2.02s
# 677:	learn: 0.0749381	total: 4.24s	remaining: 2.01s
# 678:	learn: 0.0749026	total: 4.25s	remaining: 2.01s
# 679:	learn: 0.0748626	total: 4.25s	remaining: 2s
# 680:	learn: 0.0748338	total: 4.26s	remaining: 2s
# 681:	learn: 0.0748054	total: 4.27s	remaining: 1.99s
# 682:	learn: 0.0747840	total: 4.27s	remaining: 1.98s
# 683:	learn: 0.0747693	total: 4.28s	remaining: 1.98s
# 684:	learn: 0.0747442	total: 4.29s	remaining: 1.97s
# 685:	learn: 0.0746943	total: 4.29s	remaining: 1.96s
# 686:	learn: 0.0746640	total: 4.3s	remaining: 1.96s
# 687:	learn: 0.0746317	total: 4.3s	remaining: 1.95s
# 688:	learn: 0.0745906	total: 4.31s	remaining: 1.95s
# 689:	learn: 0.0745623	total: 4.32s	remaining: 1.94s
# 690:	learn: 0.0745366	total: 4.32s	remaining: 1.93s
# 691:	learn: 0.0745196	total: 4.33s	remaining: 1.93s
# 692:	learn: 0.0745053	total: 4.34s	remaining: 1.92s
# 693:	learn: 0.0744883	total: 4.34s	remaining: 1.92s
# 694:	learn: 0.0744616	total: 4.35s	remaining: 1.91s
# 695:	learn: 0.0744407	total: 4.36s	remaining: 1.91s
# 696:	learn: 0.0743721	total: 4.37s	remaining: 1.9s
# 697:	learn: 0.0743340	total: 4.38s	remaining: 1.9s
# 698:	learn: 0.0743053	total: 4.39s	remaining: 1.89s
# 699:	learn: 0.0742969	total: 4.4s	remaining: 1.88s
# 700:	learn: 0.0742898	total: 4.41s	remaining: 1.88s
# 701:	learn: 0.0742744	total: 4.41s	remaining: 1.87s
# 702:	learn: 0.0742661	total: 4.42s	remaining: 1.87s
# 703:	learn: 0.0742163	total: 4.43s	remaining: 1.86s
# 704:	learn: 0.0742003	total: 4.43s	remaining: 1.85s
# 705:	learn: 0.0741654	total: 4.44s	remaining: 1.85s
# 706:	learn: 0.0741264	total: 4.45s	remaining: 1.84s
# 707:	learn: 0.0741156	total: 4.45s	remaining: 1.84s
# 708:	learn: 0.0741093	total: 4.46s	remaining: 1.83s
# 709:	learn: 0.0740838	total: 4.47s	remaining: 1.82s
# 710:	learn: 0.0740718	total: 4.47s	remaining: 1.82s
# 711:	learn: 0.0740243	total: 4.48s	remaining: 1.81s
# 712:	learn: 0.0739454	total: 4.49s	remaining: 1.81s
# 713:	learn: 0.0739263	total: 4.49s	remaining: 1.8s
# 714:	learn: 0.0739025	total: 4.5s	remaining: 1.79s
# 715:	learn: 0.0738929	total: 4.5s	remaining: 1.79s
# 716:	learn: 0.0738626	total: 4.51s	remaining: 1.78s
# 717:	learn: 0.0738243	total: 4.52s	remaining: 1.77s
# 718:	learn: 0.0738076	total: 4.52s	remaining: 1.77s
# 719:	learn: 0.0737678	total: 4.53s	remaining: 1.76s
# 720:	learn: 0.0737287	total: 4.54s	remaining: 1.75s
# 721:	learn: 0.0736780	total: 4.54s	remaining: 1.75s
# 722:	learn: 0.0736581	total: 4.55s	remaining: 1.74s
# 723:	learn: 0.0736470	total: 4.55s	remaining: 1.74s
# 724:	learn: 0.0736296	total: 4.56s	remaining: 1.73s
# 725:	learn: 0.0736102	total: 4.57s	remaining: 1.72s
# 726:	learn: 0.0735793	total: 4.57s	remaining: 1.72s
# 727:	learn: 0.0735477	total: 4.58s	remaining: 1.71s
# 728:	learn: 0.0735145	total: 4.59s	remaining: 1.71s
# 729:	learn: 0.0734984	total: 4.59s	remaining: 1.7s
# 730:	learn: 0.0734825	total: 4.6s	remaining: 1.69s
# 731:	learn: 0.0734548	total: 4.61s	remaining: 1.69s
# 732:	learn: 0.0733703	total: 4.62s	remaining: 1.68s
# 733:	learn: 0.0733448	total: 4.62s	remaining: 1.67s
# 734:	learn: 0.0733000	total: 4.63s	remaining: 1.67s
# 735:	learn: 0.0732751	total: 4.63s	remaining: 1.66s
# 736:	learn: 0.0732360	total: 4.64s	remaining: 1.66s
# 737:	learn: 0.0731979	total: 4.65s	remaining: 1.65s
# 738:	learn: 0.0731628	total: 4.65s	remaining: 1.64s
# 739:	learn: 0.0731295	total: 4.66s	remaining: 1.64s
# 740:	learn: 0.0730951	total: 4.66s	remaining: 1.63s
# 741:	learn: 0.0730614	total: 4.67s	remaining: 1.62s
# 742:	learn: 0.0730294	total: 4.68s	remaining: 1.62s
# 743:	learn: 0.0730182	total: 4.68s	remaining: 1.61s
# 744:	learn: 0.0729804	total: 4.69s	remaining: 1.6s
# 745:	learn: 0.0729459	total: 4.7s	remaining: 1.6s
# 746:	learn: 0.0729214	total: 4.7s	remaining: 1.59s
# 747:	learn: 0.0728772	total: 4.71s	remaining: 1.58s
# 748:	learn: 0.0728490	total: 4.71s	remaining: 1.58s
# 749:	learn: 0.0728106	total: 4.72s	remaining: 1.57s
# 750:	learn: 0.0727905	total: 4.72s	remaining: 1.56s
# 751:	learn: 0.0727873	total: 4.73s	remaining: 1.56s
# 752:	learn: 0.0727519	total: 4.74s	remaining: 1.55s
# 753:	learn: 0.0727148	total: 4.74s	remaining: 1.55s
# 754:	learn: 0.0727027	total: 4.75s	remaining: 1.54s
# 755:	learn: 0.0726667	total: 4.76s	remaining: 1.53s
# 756:	learn: 0.0726490	total: 4.76s	remaining: 1.53s
# 757:	learn: 0.0726399	total: 4.77s	remaining: 1.52s
# 758:	learn: 0.0726099	total: 4.77s	remaining: 1.51s
# 759:	learn: 0.0725813	total: 4.78s	remaining: 1.51s
# 760:	learn: 0.0725386	total: 4.78s	remaining: 1.5s
# 761:	learn: 0.0725282	total: 4.79s	remaining: 1.5s
# 762:	learn: 0.0725212	total: 4.8s	remaining: 1.49s
# 763:	learn: 0.0724894	total: 4.81s	remaining: 1.49s
# 764:	learn: 0.0724699	total: 4.82s	remaining: 1.48s
# 765:	learn: 0.0724431	total: 4.82s	remaining: 1.47s
# 766:	learn: 0.0723901	total: 4.83s	remaining: 1.47s
# 767:	learn: 0.0723621	total: 4.83s	remaining: 1.46s
# 768:	learn: 0.0723362	total: 4.84s	remaining: 1.45s
# 769:	learn: 0.0723050	total: 4.85s	remaining: 1.45s
# 770:	learn: 0.0722356	total: 4.85s	remaining: 1.44s
# 771:	learn: 0.0722223	total: 4.86s	remaining: 1.44s
# 772:	learn: 0.0721772	total: 4.87s	remaining: 1.43s
# 773:	learn: 0.0721646	total: 4.87s	remaining: 1.42s
# 774:	learn: 0.0721336	total: 4.88s	remaining: 1.42s
# 775:	learn: 0.0720985	total: 4.88s	remaining: 1.41s
# 776:	learn: 0.0720810	total: 4.89s	remaining: 1.4s
# 777:	learn: 0.0720608	total: 4.9s	remaining: 1.4s
# 778:	learn: 0.0720247	total: 4.9s	remaining: 1.39s
# 779:	learn: 0.0719737	total: 4.91s	remaining: 1.38s
# 780:	learn: 0.0719403	total: 4.91s	remaining: 1.38s
# 781:	learn: 0.0719273	total: 4.92s	remaining: 1.37s
# 782:	learn: 0.0719075	total: 4.92s	remaining: 1.36s
# 783:	learn: 0.0718929	total: 4.93s	remaining: 1.36s
# 784:	learn: 0.0718691	total: 4.94s	remaining: 1.35s
# 785:	learn: 0.0718564	total: 4.94s	remaining: 1.34s
# 786:	learn: 0.0718477	total: 4.95s	remaining: 1.34s
# 787:	learn: 0.0718327	total: 4.95s	remaining: 1.33s
# 788:	learn: 0.0717900	total: 4.96s	remaining: 1.33s
# 789:	learn: 0.0717689	total: 4.97s	remaining: 1.32s
# 790:	learn: 0.0717384	total: 4.97s	remaining: 1.31s
# 791:	learn: 0.0717093	total: 4.98s	remaining: 1.31s
# 792:	learn: 0.0716918	total: 4.99s	remaining: 1.3s
# 793:	learn: 0.0716495	total: 5s	remaining: 1.3s
# 794:	learn: 0.0716322	total: 5.01s	remaining: 1.29s
# 795:	learn: 0.0716294	total: 5.02s	remaining: 1.29s
# 796:	learn: 0.0716012	total: 5.03s	remaining: 1.28s
# 797:	learn: 0.0715942	total: 5.03s	remaining: 1.27s
# 798:	learn: 0.0715596	total: 5.04s	remaining: 1.27s
# 799:	learn: 0.0714980	total: 5.05s	remaining: 1.26s
# 800:	learn: 0.0714662	total: 5.05s	remaining: 1.25s
# 801:	learn: 0.0714320	total: 5.06s	remaining: 1.25s
# 802:	learn: 0.0714272	total: 5.07s	remaining: 1.24s
# 803:	learn: 0.0714062	total: 5.07s	remaining: 1.24s
# 804:	learn: 0.0713978	total: 5.08s	remaining: 1.23s
# 805:	learn: 0.0713627	total: 5.09s	remaining: 1.23s
# 806:	learn: 0.0713532	total: 5.1s	remaining: 1.22s
# 807:	learn: 0.0713430	total: 5.1s	remaining: 1.21s
# 808:	learn: 0.0713369	total: 5.11s	remaining: 1.21s
# 809:	learn: 0.0712933	total: 5.12s	remaining: 1.2s
# 810:	learn: 0.0712818	total: 5.12s	remaining: 1.19s
# 811:	learn: 0.0712583	total: 5.13s	remaining: 1.19s
# 812:	learn: 0.0712346	total: 5.14s	remaining: 1.18s
# 813:	learn: 0.0712196	total: 5.15s	remaining: 1.18s
# 814:	learn: 0.0711915	total: 5.15s	remaining: 1.17s
# 815:	learn: 0.0711821	total: 5.16s	remaining: 1.16s
# 816:	learn: 0.0711705	total: 5.17s	remaining: 1.16s
# 817:	learn: 0.0711571	total: 5.17s	remaining: 1.15s
# 818:	learn: 0.0711247	total: 5.18s	remaining: 1.15s
# 819:	learn: 0.0711101	total: 5.19s	remaining: 1.14s
# 820:	learn: 0.0711015	total: 5.2s	remaining: 1.13s
# 821:	learn: 0.0710709	total: 5.2s	remaining: 1.13s
# 822:	learn: 0.0710541	total: 5.21s	remaining: 1.12s
# 823:	learn: 0.0710478	total: 5.22s	remaining: 1.11s
# 824:	learn: 0.0710204	total: 5.22s	remaining: 1.11s
# 825:	learn: 0.0709900	total: 5.23s	remaining: 1.1s
# 826:	learn: 0.0709666	total: 5.24s	remaining: 1.09s
# 827:	learn: 0.0709385	total: 5.25s	remaining: 1.09s
# 828:	learn: 0.0709151	total: 5.25s	remaining: 1.08s
# 829:	learn: 0.0708965	total: 5.26s	remaining: 1.08s
# 830:	learn: 0.0708775	total: 5.27s	remaining: 1.07s
# 831:	learn: 0.0708429	total: 5.27s	remaining: 1.06s
# 832:	learn: 0.0708112	total: 5.28s	remaining: 1.06s
# 833:	learn: 0.0707836	total: 5.29s	remaining: 1.05s
# 834:	learn: 0.0707527	total: 5.29s	remaining: 1.05s
# 835:	learn: 0.0707375	total: 5.3s	remaining: 1.04s
# 836:	learn: 0.0707092	total: 5.31s	remaining: 1.03s
# 837:	learn: 0.0706806	total: 5.32s	remaining: 1.03s
# 838:	learn: 0.0706437	total: 5.33s	remaining: 1.02s
# 839:	learn: 0.0706173	total: 5.33s	remaining: 1.01s
# 840:	learn: 0.0705799	total: 5.34s	remaining: 1.01s
# 841:	learn: 0.0705415	total: 5.35s	remaining: 1s
# 842:	learn: 0.0705296	total: 5.36s	remaining: 997ms
# 843:	learn: 0.0705103	total: 5.36s	remaining: 991ms
# 844:	learn: 0.0704758	total: 5.37s	remaining: 985ms
# 845:	learn: 0.0704595	total: 5.38s	remaining: 979ms
# 846:	learn: 0.0703973	total: 5.39s	remaining: 973ms
# 847:	learn: 0.0703681	total: 5.39s	remaining: 967ms
# 848:	learn: 0.0703472	total: 5.4s	remaining: 961ms
# 849:	learn: 0.0703216	total: 5.41s	remaining: 955ms
# 850:	learn: 0.0702847	total: 5.42s	remaining: 948ms
# 851:	learn: 0.0702296	total: 5.42s	remaining: 942ms
# 852:	learn: 0.0702029	total: 5.43s	remaining: 936ms
# 853:	learn: 0.0701817	total: 5.44s	remaining: 930ms
# 854:	learn: 0.0701723	total: 5.45s	remaining: 924ms
# 855:	learn: 0.0701393	total: 5.45s	remaining: 917ms
# 856:	learn: 0.0701224	total: 5.46s	remaining: 911ms
# 857:	learn: 0.0700944	total: 5.47s	remaining: 905ms
# 858:	learn: 0.0700738	total: 5.48s	remaining: 899ms
# 859:	learn: 0.0700646	total: 5.48s	remaining: 892ms
# 860:	learn: 0.0700417	total: 5.49s	remaining: 886ms
# 861:	learn: 0.0700200	total: 5.5s	remaining: 880ms
# 862:	learn: 0.0700084	total: 5.5s	remaining: 874ms
# 863:	learn: 0.0699891	total: 5.51s	remaining: 867ms
# 864:	learn: 0.0699669	total: 5.52s	remaining: 861ms
# 865:	learn: 0.0699581	total: 5.53s	remaining: 855ms
# 866:	learn: 0.0699324	total: 5.53s	remaining: 849ms
# 867:	learn: 0.0698987	total: 5.54s	remaining: 843ms
# 868:	learn: 0.0698908	total: 5.55s	remaining: 836ms
# 869:	learn: 0.0698783	total: 5.55s	remaining: 830ms
# 870:	learn: 0.0698493	total: 5.56s	remaining: 824ms
# 871:	learn: 0.0698225	total: 5.57s	remaining: 817ms
# 872:	learn: 0.0698138	total: 5.58s	remaining: 811ms
# 873:	learn: 0.0698091	total: 5.58s	remaining: 805ms
# 874:	learn: 0.0697834	total: 5.59s	remaining: 799ms
# 875:	learn: 0.0697682	total: 5.6s	remaining: 792ms
# 876:	learn: 0.0697334	total: 5.61s	remaining: 786ms
# 877:	learn: 0.0697272	total: 5.61s	remaining: 780ms
# 878:	learn: 0.0696827	total: 5.62s	remaining: 774ms
# 879:	learn: 0.0696748	total: 5.63s	remaining: 767ms
# 880:	learn: 0.0696576	total: 5.63s	remaining: 761ms
# 881:	learn: 0.0696518	total: 5.64s	remaining: 755ms
# 882:	learn: 0.0696253	total: 5.65s	remaining: 749ms
# 883:	learn: 0.0696070	total: 5.66s	remaining: 743ms
# 884:	learn: 0.0695989	total: 5.67s	remaining: 736ms
# 885:	learn: 0.0695788	total: 5.67s	remaining: 730ms
# 886:	learn: 0.0695542	total: 5.68s	remaining: 724ms
# 887:	learn: 0.0695158	total: 5.69s	remaining: 718ms
# 888:	learn: 0.0694843	total: 5.7s	remaining: 711ms
# 889:	learn: 0.0694660	total: 5.71s	remaining: 705ms
# 890:	learn: 0.0694391	total: 5.71s	remaining: 699ms
# 891:	learn: 0.0694185	total: 5.72s	remaining: 693ms
# 892:	learn: 0.0693786	total: 5.73s	remaining: 686ms
# 893:	learn: 0.0693571	total: 5.74s	remaining: 680ms
# 894:	learn: 0.0693200	total: 5.74s	remaining: 674ms
# 895:	learn: 0.0692809	total: 5.75s	remaining: 668ms
# 896:	learn: 0.0692397	total: 5.76s	remaining: 662ms
# 897:	learn: 0.0692322	total: 5.77s	remaining: 655ms
# 898:	learn: 0.0692118	total: 5.78s	remaining: 649ms
# 899:	learn: 0.0691930	total: 5.79s	remaining: 643ms
# 900:	learn: 0.0691547	total: 5.79s	remaining: 637ms
# 901:	learn: 0.0691324	total: 5.8s	remaining: 631ms
# 902:	learn: 0.0690737	total: 5.81s	remaining: 624ms
# 903:	learn: 0.0690508	total: 5.83s	remaining: 619ms
# 904:	learn: 0.0690257	total: 5.84s	remaining: 613ms
# 905:	learn: 0.0690011	total: 5.85s	remaining: 607ms
# 906:	learn: 0.0689729	total: 5.86s	remaining: 601ms
# 907:	learn: 0.0689461	total: 5.87s	remaining: 594ms
# 908:	learn: 0.0689074	total: 5.87s	remaining: 588ms
# 909:	learn: 0.0689051	total: 5.88s	remaining: 582ms
# 910:	learn: 0.0688857	total: 5.89s	remaining: 575ms
# 911:	learn: 0.0688648	total: 5.9s	remaining: 569ms
# 912:	learn: 0.0688348	total: 5.91s	remaining: 563ms
# 913:	learn: 0.0688240	total: 5.92s	remaining: 557ms
# 914:	learn: 0.0688186	total: 5.93s	remaining: 551ms
# 915:	learn: 0.0688128	total: 5.94s	remaining: 544ms
# 916:	learn: 0.0687955	total: 5.94s	remaining: 538ms
# 917:	learn: 0.0687893	total: 5.95s	remaining: 531ms
# 918:	learn: 0.0687606	total: 5.95s	remaining: 525ms
# 919:	learn: 0.0687313	total: 5.96s	remaining: 518ms
# 920:	learn: 0.0687178	total: 5.97s	remaining: 512ms
# 921:	learn: 0.0686791	total: 5.97s	remaining: 505ms
# 922:	learn: 0.0686283	total: 5.98s	remaining: 499ms
# 923:	learn: 0.0685846	total: 5.99s	remaining: 493ms
# 924:	learn: 0.0685809	total: 6s	remaining: 486ms
# 925:	learn: 0.0685518	total: 6s	remaining: 480ms
# 926:	learn: 0.0685381	total: 6.01s	remaining: 473ms
# 927:	learn: 0.0685325	total: 6.01s	remaining: 467ms
# 928:	learn: 0.0685084	total: 6.02s	remaining: 460ms
# 929:	learn: 0.0684658	total: 6.03s	remaining: 453ms
# 930:	learn: 0.0684185	total: 6.03s	remaining: 447ms
# 931:	learn: 0.0683857	total: 6.04s	remaining: 441ms
# 932:	learn: 0.0683547	total: 6.04s	remaining: 434ms
# 933:	learn: 0.0683230	total: 6.05s	remaining: 428ms
# 934:	learn: 0.0683040	total: 6.06s	remaining: 421ms
# 935:	learn: 0.0682849	total: 6.06s	remaining: 415ms
# 936:	learn: 0.0682656	total: 6.07s	remaining: 408ms
# 937:	learn: 0.0682367	total: 6.08s	remaining: 402ms
# 938:	learn: 0.0681998	total: 6.08s	remaining: 395ms
# 939:	learn: 0.0681700	total: 6.09s	remaining: 389ms
# 940:	learn: 0.0681486	total: 6.09s	remaining: 382ms
# 941:	learn: 0.0681215	total: 6.1s	remaining: 376ms
# 942:	learn: 0.0681025	total: 6.11s	remaining: 369ms
# 943:	learn: 0.0680829	total: 6.11s	remaining: 363ms
# 944:	learn: 0.0680592	total: 6.12s	remaining: 356ms
# 945:	learn: 0.0680334	total: 6.12s	remaining: 350ms
# 946:	learn: 0.0680315	total: 6.13s	remaining: 343ms
# 947:	learn: 0.0680106	total: 6.13s	remaining: 337ms
# 948:	learn: 0.0679800	total: 6.14s	remaining: 330ms
# 949:	learn: 0.0679467	total: 6.15s	remaining: 324ms
# 950:	learn: 0.0679195	total: 6.15s	remaining: 317ms
# 951:	learn: 0.0678942	total: 6.16s	remaining: 311ms
# 952:	learn: 0.0678147	total: 6.16s	remaining: 304ms
# 953:	learn: 0.0677907	total: 6.17s	remaining: 297ms
# 954:	learn: 0.0677626	total: 6.17s	remaining: 291ms
# 955:	learn: 0.0677468	total: 6.18s	remaining: 284ms
# 956:	learn: 0.0677335	total: 6.18s	remaining: 278ms
# 957:	learn: 0.0676395	total: 6.19s	remaining: 272ms
# 958:	learn: 0.0676257	total: 6.2s	remaining: 265ms
# 959:	learn: 0.0676070	total: 6.21s	remaining: 259ms
# 960:	learn: 0.0675894	total: 6.21s	remaining: 252ms
# 961:	learn: 0.0675763	total: 6.22s	remaining: 246ms
# 962:	learn: 0.0675535	total: 6.23s	remaining: 239ms
# 963:	learn: 0.0675354	total: 6.23s	remaining: 233ms
# 964:	learn: 0.0675119	total: 6.24s	remaining: 226ms
# 965:	learn: 0.0674780	total: 6.25s	remaining: 220ms
# 966:	learn: 0.0674542	total: 6.25s	remaining: 213ms
# 967:	learn: 0.0673893	total: 6.26s	remaining: 207ms
# 968:	learn: 0.0673880	total: 6.27s	remaining: 200ms
# 969:	learn: 0.0673674	total: 6.28s	remaining: 194ms
# 970:	learn: 0.0673471	total: 6.28s	remaining: 188ms
# 971:	learn: 0.0673006	total: 6.29s	remaining: 181ms
# 972:	learn: 0.0672682	total: 6.3s	remaining: 175ms
# 973:	learn: 0.0672379	total: 6.3s	remaining: 168ms
# 974:	learn: 0.0672249	total: 6.31s	remaining: 162ms
# 975:	learn: 0.0671979	total: 6.32s	remaining: 155ms
# 976:	learn: 0.0671639	total: 6.32s	remaining: 149ms
# 977:	learn: 0.0671523	total: 6.33s	remaining: 142ms
# 978:	learn: 0.0671132	total: 6.34s	remaining: 136ms
# 979:	learn: 0.0670776	total: 6.34s	remaining: 129ms
# 980:	learn: 0.0670486	total: 6.35s	remaining: 123ms
# 981:	learn: 0.0669973	total: 6.36s	remaining: 117ms
# 982:	learn: 0.0669733	total: 6.36s	remaining: 110ms
# 983:	learn: 0.0669527	total: 6.37s	remaining: 104ms
# 984:	learn: 0.0669173	total: 6.38s	remaining: 97.1ms
# 985:	learn: 0.0668781	total: 6.38s	remaining: 90.6ms
# 986:	learn: 0.0668501	total: 6.39s	remaining: 84.2ms
# 987:	learn: 0.0668225	total: 6.4s	remaining: 77.7ms
# 988:	learn: 0.0667957	total: 6.4s	remaining: 71.2ms
# 989:	learn: 0.0667795	total: 6.41s	remaining: 64.7ms
# 990:	learn: 0.0667376	total: 6.42s	remaining: 58.3ms
# 991:	learn: 0.0667157	total: 6.42s	remaining: 51.8ms
# 992:	learn: 0.0666902	total: 6.43s	remaining: 45.3ms
# 993:	learn: 0.0666809	total: 6.43s	remaining: 38.8ms
# 994:	learn: 0.0666692	total: 6.44s	remaining: 32.4ms
# 995:	learn: 0.0666476	total: 6.44s	remaining: 25.9ms
# 996:	learn: 0.0665534	total: 6.45s	remaining: 19.4ms
# 997:	learn: 0.0665211	total: 6.46s	remaining: 12.9ms
# 998:	learn: 0.0664928	total: 6.46s	remaining: 6.47ms
# 999:	learn: 0.0664805	total: 6.47s	remaining: 0us

# %%
y_pred_cb = cb.predict(X_test)

# %%
accuracy_score(y_test,y_pred_cb)
# Out:
# 0.9605571356867993

# %% [markdown]
# ## Accuracy : 0.9605
